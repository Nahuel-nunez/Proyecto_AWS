# %%
# import requests
# from bs4 import BeautifulSoup

# # URL de la página de Wikipedia que quieres extraer
# url = 'https://es.wikipedia.org/wiki/Anexo:Videojuegos_m%C3%A1s_jugados_por_n%C3%BAmero_de_jugadores'

# # Hacer una solicitud GET a la URL
# response = requests.get(url)

# # Comprobar que la solicitud fue exitosa (código 200)
# if response.status_code == 200:
#     # Crear el objeto BeautifulSoup
#     soup = BeautifulSoup(response.content, 'html.parser')
    
#     # Extraer el título de la página
#     title = soup.find('h1').get_text()
#     print(f"Título de la página: {title}")
    
#     # Extraer el primer párrafo del contenido principal
#     first_paragraph = soup.find('p').get_text()
#     print(f"Primer párrafo: {first_paragraph}")
    
#     # Si necesitas extraer más secciones o elementos específicos, puedes usar selectores de BeautifulSoup
# else:
#     print(f"Error al acceder a la página: {response.status_code}")
# Out:
# Título de la página: Anexo:Videojuegos más jugados por número de jugadores
# Primer párrafo: Esta es una lista de los videojuegos más jugados ordenados por su cantidad total de jugadores, incluso por cuentas registradas, suscripciones o propietarios de un videojuego gratuito. En esta lista no se incluyen videojuegos por cifras de ventas oficiales; esos se encuentran en la lista de videojuegos más vendidos. Esta lista tampoco es exhaustiva, ya que los conteos de jugadores no siempre están disponibles públicamente, son confiables o están actualizados.

# %%
first_paragraph
# Out:
# 'Esta es una lista de los videojuegos más jugados ordenados por su cantidad total de jugadores, incluso por cuentas registradas, suscripciones o propietarios de un videojuego gratuito. En esta lista no se incluyen videojuegos por cifras de ventas oficiales; esos se encuentran en la lista de videojuegos más vendidos. Esta lista tampoco es exhaustiva, ya que los conteos de jugadores no siempre están disponibles públicamente, son confiables o están actualizados.\n'

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available" dir="ltr" lang="es">
# <head>
# <meta charset="utf-8"/>
# <title>Anexo:Videojuegos más jugados por número de jugadores - Wikipedia, la enciclopedia libre</title>
# <script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available";var cookie=document.cookie.match(/(?:^|; )eswikimwclientpreferences=([^;]+)/);if(cookie){cookie[1].split('%2C').forEach(function(pref){className=className.replace(new RegExp('(^| )'+pref.replace(/-clientpref-\w+$|[^\w-]+/g,'')+'-clientpref-\\w+( |$)'),'$1'+pref+'$2');});}document.documentElement.className=className;}());RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":[",\t."," \t,"],"wgDigitTransformTable":["",""],
# "wgDefaultDateFormat":"dmy","wgMonthNames":["","enero","febrero","marzo","abril","mayo","junio","julio","agosto","septiembre","octubre","noviembre","diciembre"],"wgRequestId":"a1955696-ec9e-46eb-b851-f0ed7eff5d2c","wgCanonicalNamespace":"Anexo","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":104,"wgPageName":"Anexo:Videojuegos_más_jugados_por_número_de_jugadores","wgTitle":"Videojuegos más jugados por número de jugadores","wgCurRevisionId":162114746,"wgRevisionId":162114746,"wgArticleId":8744322,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Wikipedia:Páginas con errores de referencia","Anexos:Videojuegos"],"wgPageViewLanguage":"es","wgPageContentLanguage":"es","wgPageContentModel":"wikitext","wgRelevantPageName":"Anexo:Videojuegos_más_jugados_por_número_de_jugadores","wgRelevantArticleId":8744322,"wgIsProbablyEditable":true,"wgRelevantPageIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove"
# :[],"wgNoticeProject":"wikipedia","wgCiteReferencePreviewsActive":false,"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsFlags":6,"wgVisualEditor":{"pageLanguageCode":"es","pageLanguageDir":"ltr","pageVariantFallbacks":"es"},"wgMFDisplayWikibaseDescriptions":{"search":true,"watchlist":true,"tagline":true,"nearby":true},"wgWMESchemaEditAttemptStepOversample":false,"wgWMEPageLength":40000,"wgULSCurrentAutonym":"español","wgRelatedArticlesCompat":[],"wgCentralAuthMobileDomain":false,"wgEditSubmitButtonLabelPublish":true,"wgULSPosition":"interlanguage","wgULSisCompactLinksEnabled":false,"wgVector2022LanguageInHeader":true,"wgULSisLanguageSelectorEmpty":false,"wgWikibaseItemId":"Q59296934","wgCheckUserClientHintsHeadersJsApi":["architecture","bitness","brands","fullVersionList","mobile","model","platform","platformVersion"],"GEHomepageSuggestedEditsEnableTopics":true,"wgGETopicsMatchModeEnabled":true,"wgGEStructuredTaskRejectionReasonTextInputEnabled":false,
# "wgGELevelingUpEnabledForUser":false};RLSTATE={"ext.gadget.imagenesinfobox":"ready","ext.globalCssJs.user.styles":"ready","site.styles":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","skins.vector.search.codex.styles":"ready","skins.vector.styles":"ready","skins.vector.icons":"ready","jquery.tablesorter.styles":"ready","ext.wikimediamessages.styles":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","wikibase.client.init":"ready","ext.wikimediaBadges":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.ready","jquery.tablesorter","mediawiki.toc","skins.vector.js","ext.centralNotice.geoIP","ext.centralNotice.startUp","ext.gadget.a-commons-directo","ext.gadget.ReferenceTooltips","ext.gadget.refToolbar","ext.gadget.switcher","ext.urlShortener.toolbar","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups",
# "ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.echo.centralauth","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.interface","ext.cx.eventlogging.campaigns","ext.cx.uls.quick.actions","wikibase.client.vector-2022","ext.checkUser.clientHints","wikibase.sidebar.tracking"];</script>
# <script>(RLQ=window.RLQ||[]).push(function(){mw.loader.impl(function(){return["user.options@12s5i",function($,jQuery,require,module){mw.user.tokens.set({"patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});
# }];});});</script>
# <link href="/w/load.php?lang=es&amp;modules=ext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cext.wikimediamessages.styles%7Cjquery.tablesorter.styles%7Cskins.vector.icons%2Cstyles%7Cskins.vector.search.codex.styles%7Cwikibase.client.init&amp;only=styles&amp;skin=vector-2022" rel="stylesheet"/>
# <script async="" src="/w/load.php?lang=es&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=vector-2022"></script>
# <meta content="" name="ResourceLoaderDynamicStyles"/>
# <link href="/w/load.php?lang=es&amp;modules=ext.gadget.imagenesinfobox&amp;only=styles&amp;skin=vector-2022" rel="stylesheet"/>
# <link href="/w/load.php?lang=es&amp;modules=site.styles&amp;only=styles&amp;skin=vector-2022" rel="stylesheet"/>
# <noscript><link href="/w/load.php?lang=es&amp;modules=noscript&amp;only=styles&amp;skin=vector-2022" rel="stylesheet"/></noscript>
# <meta content="MediaWiki 1.43.0-wmf.23" name="generator"/>
# <meta content="origin" name="referrer"/>
# <meta content="origin-when-cross-origin" name="referrer"/>
# <meta content="max-image-preview:standard" name="robots"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="width=1120" name="viewport"/>
# <meta content="Anexo:Videojuegos más jugados por número de jugadores - Wikipedia, la enciclopedia libre" property="og:title"/>
# <meta content="website" property="og:type"/>
# <link href="//upload.wikimedia.org" rel="preconnect"/>
# <link href="//es.m.wikipedia.org/wiki/Anexo:Videojuegos_m%C3%A1s_jugados_por_n%C3%BAmero_de_jugadores" media="only screen and (max-width: 640px)" rel="alternate"/>
# <link href="/w/index.php?title=Anexo:Videojuegos_m%C3%A1s_jugados_por_n%C3%BAmero_de_jugadores&amp;action=edit" rel="alternate" title="Editar" type="application/x-wiki"/>
# <link href="/static/apple-touch/wikipedia.png" rel="apple-touch-icon"/>
# <link href="/static/favicon/wikipedia.ico" rel="icon"/>
# <link href="/w/rest.php/v1/search" rel="search" title="Wikipedia (es)" type="application/opensearchdescription+xml"/>
# <link href="//es.wikipedia.org/w/api.php?action=rsd" rel="EditURI" type="application/rsd+xml"/>
# <link href="https://es.wikipedia.org/wiki/Anexo:Videojuegos_m%C3%A1s_jugados_por_n%C3%BAmero_de_jugadores" rel="canonical"/>
# <link href="https://creativecommons.org/licenses/by-sa/4.0/deed.es" rel="license"/>
# <link href="/w/index.php?title=Especial:CambiosRecientes&amp;feed=atom" rel="alternate" title="Canal Atom de Wikipedia" type="application/atom+xml"/>
# <link href="//meta.wikimedia.org" rel="dns-prefetch">
# <link href="//login.wikimedia.org" rel="dns-prefetch"/>
# </link></head>
# <body class="skin--responsive skin-vector skin-vector-search-vue mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-104 ns-subject mw-editable page-Anexo_Videojuegos_más_jugados_por_número_de_jugadores rootpage-Anexo_Videojuegos_más_jugados_por_número_de_jugadores skin-vector-2022 action-view"><a class="mw-jump-link" href="#bodyContent">Ir al contenido</a>
# <div class="vector-header-container">
# <header class="vector-header mw-header">
# <div class="vector-header-start">
# <nav aria-label="Sitio" class="vector-main-menu-landmark">
# <div class="vector-dropdown vector-main-menu-dropdown vector-button-flush-left vector-button-flush-right" id="vector-main-menu-dropdown">
# <input aria-haspopup="true" aria-label="Menú principal" class="vector-dropdown-checkbox" data-event-name="ui.dropdown-vector-main-menu-dropdown" id="vector-main-menu-dropdown-checkbox" role="button" type="checkbox"/>
# <label aria-hidden="true" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only" for="vector-main-menu-dropdown-checkbox" id="vector-main-menu-dropdown-label"><span class="vector-icon mw-ui-icon-menu mw-ui-icon-wikimedia-menu"></span>
# <span class="vector-dropdown-label-text">Menú principal</span>
# </label>
# <div class="vector-dropdown-content">
# <div class="vector-unpinned-container" id="vector-main-menu-unpinned-container">
# <div class="vector-main-menu vector-pinnable-element" id="vector-main-menu">
# <div class="vector-pinnable-header vector-main-menu-pinnable-header vector-pinnable-header-unpinned" data-feature-name="main-menu-pinned" data-pinnable-element-id="vector-main-menu" data-pinned-container-id="vector-main-menu-pinned-container" data-unpinned-container-id="vector-main-menu-unpinned-container">
# <div class="vector-pinnable-header-label">Menú principal</div>
# <button class="vector-pinnable-header-toggle-button vector-pinnable-header-pin-button" data-event-name="pinnable-header.vector-main-menu.pin">mover a la barra lateral</button>
# <button class="vector-pinnable-header-toggle-button vector-pinnable-header-unpin-button" data-event-name="pinnable-header.vector-main-menu.unpin">ocultar</button>
# </div>
# <div class="vector-menu mw-portlet mw-portlet-navigation" id="p-navigation">
# <div class="vector-menu-heading">
# 		Navegación
# 	</div>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# <li class="mw-list-item" id="n-mainpage-description"><a accesskey="z" href="/wiki/Wikipedia:Portada" title="Visitar la página principal [z]"><span>Portada</span></a></li><li class="mw-list-item" id="n-portal"><a href="/wiki/Portal:Comunidad" title="Acerca del proyecto, lo que puedes hacer, dónde encontrar información"><span>Portal de la comunidad</span></a></li><li class="mw-list-item" id="n-currentevents"><a href="/wiki/Portal:Actualidad" title="Encuentra información de contexto sobre acontecimientos actuales"><span>Actualidad</span></a></li><li class="mw-list-item" id="n-recentchanges"><a accesskey="r" href="/wiki/Especial:CambiosRecientes" title="Lista de cambios recientes en la wiki [r]"><span>Cambios recientes</span></a></li><li class="mw-list-item" id="n-newpages"><a href="/wiki/Especial:P%C3%A1ginasNuevas"><span>Páginas nuevas</span></a></li><li class="mw-list-item" id="n-randompage"><a accesskey="x" href="/wiki/Especial:Aleatoria" title="Cargar una página al azar [x]"><span>Página aleatoria</span></a></li><li class="mw-list-item" id="n-help"><a href="/wiki/Ayuda:Contenidos" title="El lugar para aprender"><span>Ayuda</span></a></li><li class="mw-list-item" id="n-sitesupport"><a href="//donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&amp;utm_medium=sidebar&amp;utm_campaign=C13_es.wikipedia.org&amp;uselang=es" title="Apóyanos"><span>Donaciones</span></a></li><li class="mw-list-item" id="n-bug_in_article"><a href="/wiki/Wikipedia:Informes_de_error"><span>Notificar un error</span></a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </nav>
# <a class="mw-logo" href="/wiki/Wikipedia:Portada">
# <img alt="" aria-hidden="true" class="mw-logo-icon" height="50" src="/static/images/icons/wikipedia.png" width="50"/>
# <span class="mw-logo-container skin-invert">
# <img alt="Wikipedia" class="mw-logo-wordmark" src="/static/images/mobile/copyright/wikipedia-wordmark-en.svg" style="width: 7.5em; height: 1.125em;"/>
# <img alt="La enciclopedia libre" class="mw-logo-tagline" height="13" src="/static/images/mobile/copyright/wikipedia-tagline-es.svg" style="width: 7.5em; height: 0.8125em;" width="120"/>
# </span>
# </a>
# </div>
# <div class="vector-header-end">
# <div class="vector-search-box-vue vector-search-box-collapses vector-search-box-show-thumbnail vector-search-box-auto-expand-width vector-search-box" id="p-search" role="search">
# <a accesskey="f" class="cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only search-toggle" href="/wiki/Especial:Buscar" title="Buscar en este wiki [f]"><span class="vector-icon mw-ui-icon-search mw-ui-icon-wikimedia-search"></span>
# <span>Buscar</span>
# </a>
# <div class="vector-typeahead-search-container">
# <div class="cdx-typeahead-search cdx-typeahead-search--show-thumbnail cdx-typeahead-search--auto-expand-width">
# <form action="/w/index.php" class="cdx-search-input cdx-search-input--has-end-button" id="searchform">
# <div class="cdx-search-input__input-wrapper" data-search-loc="header-moved" id="simpleSearch">
# <div class="cdx-text-input cdx-text-input--has-start-icon">
# <input accesskey="f" aria-label="Buscar en Wikipedia" autocapitalize="sentences" class="cdx-text-input__input" id="searchInput" name="search" placeholder="Buscar en Wikipedia" title="Buscar en este wiki [f]" type="search"/>
# <span class="cdx-text-input__icon cdx-text-input__start-icon"></span>
# </div>
# <input name="title" type="hidden" value="Especial:Buscar"/>
# </div>
# <button class="cdx-button cdx-search-input__end-button">Buscar</button>
# </form>
# </div>
# </div>
# </div>
# <nav aria-label="Herramientas personales" class="vector-user-links vector-user-links-wide">
# <div class="vector-user-links-main">
# <div class="vector-menu mw-portlet emptyPortlet" id="p-vector-user-menu-preferences">
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# </ul>
# </div>
# </div>
# <div class="vector-menu mw-portlet emptyPortlet" id="p-vector-user-menu-userpage">
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# </ul>
# </div>
# </div>
# <nav aria-label="Apariencia" class="vector-appearance-landmark">
# <div class="vector-dropdown" id="vector-appearance-dropdown" title="Change the appearance of the page's font size, width, and color">
# <input aria-haspopup="true" aria-label="Apariencia" class="vector-dropdown-checkbox" data-event-name="ui.dropdown-vector-appearance-dropdown" id="vector-appearance-dropdown-checkbox" role="button" type="checkbox"/>
# <label aria-hidden="true" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only" for="vector-appearance-dropdown-checkbox" id="vector-appearance-dropdown-label"><span class="vector-icon mw-ui-icon-appearance mw-ui-icon-wikimedia-appearance"></span>
# <span class="vector-dropdown-label-text">Apariencia</span>
# </label>
# <div class="vector-dropdown-content">
# <div class="vector-unpinned-container" id="vector-appearance-unpinned-container">
# </div>
# </div>
# </div>
# </nav>
# <div class="vector-menu mw-portlet emptyPortlet" id="p-vector-user-menu-notifications">
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# </ul>
# </div>
# </div>
# <div class="vector-menu mw-portlet" id="p-vector-user-menu-overflow">
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# <li class="user-links-collapsible-item mw-list-item user-links-collapsible-item" id="pt-createaccount-2"><a class="" data-mw="interface" href="/w/index.php?title=Especial:Crear_una_cuenta&amp;returnto=Anexo%3AVideojuegos+m%C3%A1s+jugados+por+n%C3%BAmero+de+jugadores" title="Te recomendamos crear una cuenta e iniciar sesión; sin embargo, no es obligatorio"><span>Crear una cuenta</span></a>
# </li>
# <li class="user-links-collapsible-item mw-list-item user-links-collapsible-item" id="pt-login-2"><a accesskey="o" class="" data-mw="interface" href="/w/index.php?title=Especial:Entrar&amp;returnto=Anexo%3AVideojuegos+m%C3%A1s+jugados+por+n%C3%BAmero+de+jugadores" title="Te recomendamos iniciar sesión, aunque no es obligatorio [o]"><span>Acceder</span></a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="vector-dropdown vector-user-menu vector-button-flush-right vector-user-menu-logged-out" id="vector-user-links-dropdown" title="Más opciones">
# <input aria-haspopup="true" aria-label="Herramientas personales" class="vector-dropdown-checkbox" data-event-name="ui.dropdown-vector-user-links-dropdown" id="vector-user-links-dropdown-checkbox" role="button" type="checkbox"/>
# <label aria-hidden="true" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only" for="vector-user-links-dropdown-checkbox" id="vector-user-links-dropdown-label"><span class="vector-icon mw-ui-icon-ellipsis mw-ui-icon-wikimedia-ellipsis"></span>
# <span class="vector-dropdown-label-text">Herramientas personales</span>
# </label>
# <div class="vector-dropdown-content">
# <div class="vector-menu mw-portlet mw-portlet-personal user-links-collapsible-item" id="p-personal" title="Menú de usuario">
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# <li class="user-links-collapsible-item mw-list-item" id="pt-createaccount"><a href="/w/index.php?title=Especial:Crear_una_cuenta&amp;returnto=Anexo%3AVideojuegos+m%C3%A1s+jugados+por+n%C3%BAmero+de+jugadores" title="Te recomendamos crear una cuenta e iniciar sesión; sin embargo, no es obligatorio"><span class="vector-icon mw-ui-icon-userAdd mw-ui-icon-wikimedia-userAdd"></span> <span>Crear una cuenta</span></a></li><li class="user-links-collapsible-item mw-list-item" id="pt-login"><a accesskey="o" href="/w/index.php?title=Especial:Entrar&amp;returnto=Anexo%3AVideojuegos+m%C3%A1s+jugados+por+n%C3%BAmero+de+jugadores" title="Te recomendamos iniciar sesión, aunque no es obligatorio [o]"><span class="vector-icon mw-ui-icon-logIn mw-ui-icon-wikimedia-logIn"></span> <span>Acceder</span></a></li>
# </ul>
# </div>
# </div>
# <div class="vector-menu mw-portlet mw-portlet-user-menu-anon-editor" id="p-user-menu-anon-editor">
# <div class="vector-menu-heading">
# 		Páginas para editores desconectados <a aria-label="Obtenga más información sobre editar" href="/wiki/Ayuda:Introducci%C3%B3n"><span>más información</span></a>
# </div>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# <li class="mw-list-item" id="pt-anoncontribs"><a accesskey="y" href="/wiki/Especial:MisContribuciones" title="Una lista de modificaciones hechas desde esta dirección IP [y]"><span>Contribuciones</span></a></li><li class="mw-list-item" id="pt-anontalk"><a accesskey="n" href="/wiki/Especial:MiDiscusi%C3%B3n" title="Discusión sobre ediciones hechas desde esta dirección IP [n]"><span>Discusión</span></a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </nav>
# </div>
# </header>
# </div>
# <div class="mw-page-container">
# <div class="mw-page-container-inner">
# <div class="vector-sitenotice-container">
# <div id="siteNotice"><!-- CentralNotice --></div>
# </div>
# <div class="vector-column-start">
# <div class="vector-main-menu-container">
# <div id="mw-navigation">
# <nav aria-label="Sitio" class="vector-main-menu-landmark" id="mw-panel">
# <div class="vector-pinned-container" id="vector-main-menu-pinned-container">
# </div>
# </nav>
# </div>
# </div>
# <div class="vector-sticky-pinned-container">
# <nav aria-label="Contenidos" class="mw-table-of-contents-container vector-toc-landmark" data-event-name="ui.sidebar-toc" id="mw-panel-toc">
# <div class="vector-pinned-container" id="vector-toc-pinned-container">
# <div class="vector-toc vector-pinnable-element" id="vector-toc">
# <div class="vector-pinnable-header vector-toc-pinnable-header vector-pinnable-header-pinned" data-feature-name="toc-pinned" data-pinnable-element-id="vector-toc">
# <h2 class="vector-pinnable-header-label">Contenidos</h2>
# <button class="vector-pinnable-header-toggle-button vector-pinnable-header-pin-button" data-event-name="pinnable-header.vector-toc.pin">mover a la barra lateral</button>
# <button class="vector-pinnable-header-toggle-button vector-pinnable-header-unpin-button" data-event-name="pinnable-header.vector-toc.unpin">ocultar</button>
# </div>
# <ul class="vector-toc-contents" id="mw-panel-toc-list">
# <li class="vector-toc-list-item vector-toc-level-1" id="toc-mw-content-text">
# <a class="vector-toc-link" href="#">
# <div class="vector-toc-text">Inicio</div>
# </a>
# </li>
# <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-Lista">
# <a class="vector-toc-link" href="#Lista">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">1</span>
# <span>Lista</span>
# </div>
# </a>
# <ul class="vector-toc-list" id="toc-Lista-sublist">
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-Véase_también">
# <a class="vector-toc-link" href="#Véase_también">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">2</span>
# <span>Véase también</span>
# </div>
# </a>
# <ul class="vector-toc-list" id="toc-Véase_también-sublist">
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-Notas">
# <a class="vector-toc-link" href="#Notas">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">3</span>
# <span>Notas</span>
# </div>
# </a>
# <ul class="vector-toc-list" id="toc-Notas-sublist">
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-Referencias">
# <a class="vector-toc-link" href="#Referencias">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">4</span>
# <span>Referencias</span>
# </div>
# </a>
# <ul class="vector-toc-list" id="toc-Referencias-sublist">
# </ul>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# </div>
# </div>
# <div class="mw-content-container">
# <main class="mw-body" id="content">
# <header class="mw-body-header vector-page-titlebar">
# <nav aria-label="Contenidos" class="vector-toc-landmark">
# <div class="vector-dropdown vector-page-titlebar-toc vector-button-flush-left" id="vector-page-titlebar-toc">
# <input aria-haspopup="true" aria-label="Cambiar a la tabla de contenidos" class="vector-dropdown-checkbox" data-event-name="ui.dropdown-vector-page-titlebar-toc" id="vector-page-titlebar-toc-checkbox" role="button" type="checkbox"/>
# <label aria-hidden="true" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only" for="vector-page-titlebar-toc-checkbox" id="vector-page-titlebar-toc-label"><span class="vector-icon mw-ui-icon-listBullet mw-ui-icon-wikimedia-listBullet"></span>
# <span class="vector-dropdown-label-text">Cambiar a la tabla de contenidos</span>
# </label>
# <div class="vector-dropdown-content">
# <div class="vector-unpinned-container" id="vector-page-titlebar-toc-unpinned-container">
# </div>
# </div>
# </div>
# </nav>
# <h1 class="firstHeading mw-first-heading" id="firstHeading"><span class="mw-page-title-namespace">Anexo</span><span class="mw-page-title-separator">:</span><span class="mw-page-title-main">Videojuegos más jugados por número de jugadores</span></h1>
# <div class="vector-dropdown mw-portlet mw-portlet-lang" id="p-lang-btn">
# <input aria-haspopup="true" aria-label="Ir a un artículo en otro idioma. Disponible en 2 idiomas" class="vector-dropdown-checkbox mw-interlanguage-selector" data-event-name="ui.dropdown-p-lang-btn" id="p-lang-btn-checkbox" role="button" type="checkbox"/>
# <label aria-hidden="true" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--action-progressive mw-portlet-lang-heading-2" for="p-lang-btn-checkbox" id="p-lang-btn-label"><span class="vector-icon mw-ui-icon-language-progressive mw-ui-icon-wikimedia-language-progressive"></span>
# <span class="vector-dropdown-label-text">2 idiomas</span>
# </label>
# <div class="vector-dropdown-content">
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# <li class="interlanguage-link interwiki-ar mw-list-item"><a class="interlanguage-link-target" data-language-autonym="العربية" data-language-local-name="árabe" data-title="قائمة ألعاب الفيديو حسب عدد اللاعبين" href="https://ar.wikipedia.org/wiki/%D9%82%D8%A7%D8%A6%D9%85%D8%A9_%D8%A3%D9%84%D8%B9%D8%A7%D8%A8_%D8%A7%D9%84%D9%81%D9%8A%D8%AF%D9%8A%D9%88_%D8%AD%D8%B3%D8%A8_%D8%B9%D8%AF%D8%AF_%D8%A7%D9%84%D9%84%D8%A7%D8%B9%D8%A8%D9%8A%D9%86" hreflang="ar" lang="ar" title="قائمة ألعاب الفيديو حسب عدد اللاعبين (árabe)"><span>العربية</span></a></li><li class="interlanguage-link interwiki-qu mw-list-item"><a class="interlanguage-link-target" data-language-autonym="Runa Simi" data-language-local-name="quechua" data-title="Kuyuq rikch'a puklla aswan achka pukllarqanku" href="https://qu.wikipedia.org/wiki/Kuyuq_rikch%27a_puklla_aswan_achka_pukllarqanku" hreflang="qu" lang="qu" title="Kuyuq rikch'a puklla aswan achka pukllarqanku (quechua)"><span>Runa Simi</span></a></li>
# </ul>
# <div class="after-portlet after-portlet-lang"><span class="wb-langlinks-edit wb-langlinks-link"><a class="wbc-editpage" href="https://www.wikidata.org/wiki/Special:EntityPage/Q59296934#sitelinks-wikipedia" title="Editar enlaces interlingüísticos">Editar enlaces</a></span></div>
# </div>
# </div>
# </div>
# </header>
# <div class="vector-page-toolbar">
# <div class="vector-page-toolbar-container">
# <div id="left-navigation">
# <nav aria-label="Espacios de nombres">
# <div class="vector-menu vector-menu-tabs mw-portlet mw-portlet-associated-pages" id="p-associated-pages">
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# <li class="selected vector-tab-noicon mw-list-item" id="ca-nstab-anexo"><a accesskey="c" href="/wiki/Anexo:Videojuegos_m%C3%A1s_jugados_por_n%C3%BAmero_de_jugadores" title="Ver la página de contenido [c]"><span>Anexo</span></a></li><li class="vector-tab-noicon mw-list-item" id="ca-talk"><a accesskey="t" href="/wiki/Anexo_discusi%C3%B3n:Videojuegos_m%C3%A1s_jugados_por_n%C3%BAmero_de_jugadores" rel="discussion" title="Discusión acerca de la página [t]"><span>Discusión</span></a></li>
# </ul>
# </div>
# </div>
# <div class="vector-dropdown emptyPortlet" id="vector-variants-dropdown">
# <input aria-haspopup="true" aria-label="Cambiar variante de idioma" class="vector-dropdown-checkbox" data-event-name="ui.dropdown-vector-variants-dropdown" id="vector-variants-dropdown-checkbox" role="button" type="checkbox"/>
# <label aria-hidden="true" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet" for="vector-variants-dropdown-checkbox" id="vector-variants-dropdown-label"><span class="vector-dropdown-label-text">español</span>
# </label>
# <div class="vector-dropdown-content">
# <div class="vector-menu mw-portlet mw-portlet-variants emptyPortlet" id="p-variants">
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# </ul>
# </div>
# </div>
# </div>
# </div>
# </nav>
# </div>
# <div class="vector-collapsible" id="right-navigation">
# <nav aria-label="Vistas">
# <div class="vector-menu vector-menu-tabs mw-portlet mw-portlet-views" id="p-views">
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# <li class="selected vector-tab-noicon mw-list-item" id="ca-view"><a href="/wiki/Anexo:Videojuegos_m%C3%A1s_jugados_por_n%C3%BAmero_de_jugadores"><span>Leer</span></a></li><li class="vector-tab-noicon mw-list-item" id="ca-edit"><a accesskey="e" href="/w/index.php?title=Anexo:Videojuegos_m%C3%A1s_jugados_por_n%C3%BAmero_de_jugadores&amp;action=edit" title="Editar esta página [e]"><span>Editar</span></a></li><li class="vector-tab-noicon mw-list-item" id="ca-history"><a accesskey="h" href="/w/index.php?title=Anexo:Videojuegos_m%C3%A1s_jugados_por_n%C3%BAmero_de_jugadores&amp;action=history" title="Versiones anteriores de esta página [h]"><span>Ver historial</span></a></li>
# </ul>
# </div>
# </div>
# </nav>
# <nav aria-label="Página de herramientas" class="vector-page-tools-landmark">
# <div class="vector-dropdown vector-page-tools-dropdown" id="vector-page-tools-dropdown">
# <input aria-haspopup="true" aria-label="Herramientas" class="vector-dropdown-checkbox" data-event-name="ui.dropdown-vector-page-tools-dropdown" id="vector-page-tools-dropdown-checkbox" role="button" type="checkbox"/>
# <label aria-hidden="true" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet" for="vector-page-tools-dropdown-checkbox" id="vector-page-tools-dropdown-label"><span class="vector-dropdown-label-text">Herramientas</span>
# </label>
# <div class="vector-dropdown-content">
# <div class="vector-unpinned-container" id="vector-page-tools-unpinned-container">
# <div class="vector-page-tools vector-pinnable-element" id="vector-page-tools">
# <div class="vector-pinnable-header vector-page-tools-pinnable-header vector-pinnable-header-unpinned" data-feature-name="page-tools-pinned" data-pinnable-element-id="vector-page-tools" data-pinned-container-id="vector-page-tools-pinned-container" data-unpinned-container-id="vector-page-tools-unpinned-container">
# <div class="vector-pinnable-header-label">Herramientas</div>
# <button class="vector-pinnable-header-toggle-button vector-pinnable-header-pin-button" data-event-name="pinnable-header.vector-page-tools.pin">mover a la barra lateral</button>
# <button class="vector-pinnable-header-toggle-button vector-pinnable-header-unpin-button" data-event-name="pinnable-header.vector-page-tools.unpin">ocultar</button>
# </div>
# <div class="vector-menu mw-portlet mw-portlet-cactions emptyPortlet vector-has-collapsible-items" id="p-cactions" title="Más opciones">
# <div class="vector-menu-heading">
# 		Acciones
# 	</div>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# <li class="selected vector-more-collapsible-item mw-list-item" id="ca-more-view"><a href="/wiki/Anexo:Videojuegos_m%C3%A1s_jugados_por_n%C3%BAmero_de_jugadores"><span>Leer</span></a></li><li class="vector-more-collapsible-item mw-list-item" id="ca-more-edit"><a accesskey="e" href="/w/index.php?title=Anexo:Videojuegos_m%C3%A1s_jugados_por_n%C3%BAmero_de_jugadores&amp;action=edit" title="Editar esta página [e]"><span>Editar</span></a></li><li class="vector-more-collapsible-item mw-list-item" id="ca-more-history"><a href="/w/index.php?title=Anexo:Videojuegos_m%C3%A1s_jugados_por_n%C3%BAmero_de_jugadores&amp;action=history"><span>Ver historial</span></a></li>
# </ul>
# </div>
# </div>
# <div class="vector-menu mw-portlet mw-portlet-tb" id="p-tb">
# <div class="vector-menu-heading">
# 		General
# 	</div>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# <li class="mw-list-item" id="t-whatlinkshere"><a accesskey="j" href="/wiki/Especial:LoQueEnlazaAqu%C3%AD/Anexo:Videojuegos_m%C3%A1s_jugados_por_n%C3%BAmero_de_jugadores" title="Lista de todas las páginas de la wiki que enlazan aquí [j]"><span>Lo que enlaza aquí</span></a></li><li class="mw-list-item" id="t-recentchangeslinked"><a accesskey="k" href="/wiki/Especial:CambiosEnEnlazadas/Anexo:Videojuegos_m%C3%A1s_jugados_por_n%C3%BAmero_de_jugadores" rel="nofollow" title="Cambios recientes en las páginas que enlazan con esta [k]"><span>Cambios en enlazadas</span></a></li><li class="mw-list-item" id="t-upload"><a accesskey="u" href="//commons.wikimedia.org/wiki/Special:UploadWizard?uselang=es" title="Subir archivos [u]"><span>Subir archivo</span></a></li><li class="mw-list-item" id="t-specialpages"><a accesskey="q" href="/wiki/Especial:P%C3%A1ginasEspeciales" title="Lista de todas las páginas especiales [q]"><span>Páginas especiales</span></a></li><li class="mw-list-item" id="t-permalink"><a href="/w/index.php?title=Anexo:Videojuegos_m%C3%A1s_jugados_por_n%C3%BAmero_de_jugadores&amp;oldid=162114746" title="Enlace permanente a esta versión de la página"><span>Enlace permanente</span></a></li><li class="mw-list-item" id="t-info"><a href="/w/index.php?title=Anexo:Videojuegos_m%C3%A1s_jugados_por_n%C3%BAmero_de_jugadores&amp;action=info" title="Más información sobre esta página"><span>Información de la página</span></a></li><li class="mw-list-item" id="t-cite"><a href="/w/index.php?title=Especial:Citar&amp;page=Anexo%3AVideojuegos_m%C3%A1s_jugados_por_n%C3%BAmero_de_jugadores&amp;id=162114746&amp;wpFormIdentifier=titleform" title="Información sobre cómo citar esta página"><span>Citar esta página</span></a></li><li class="mw-list-item" id="t-urlshortener"><a href="/w/index.php?title=Especial:Acortador_de_URL&amp;url=https%3A%2F%2Fes.wikipedia.org%2Fwiki%2FAnexo%3AVideojuegos_m%25C3%25A1s_jugados_por_n%25C3%25BAmero_de_jugadores"><span>Obtener URL acortado</span></a></li><li class="mw-list-item" id="t-urlshortener-qrcode"><a href="/w/index.php?title=Especial:QrCode&amp;url=https%3A%2F%2Fes.wikipedia.org%2Fwiki%2FAnexo%3AVideojuegos_m%25C3%25A1s_jugados_por_n%25C3%25BAmero_de_jugadores"><span>Descargar código QR</span></a></li><li class="mw-list-item" id="t-wikibase"><a accesskey="g" href="https://www.wikidata.org/wiki/Special:EntityPage/Q59296934" title="Enlace al elemento conectado del repositorio de datos [g]"><span>Elemento de Wikidata</span></a></li>
# </ul>
# </div>
# </div>
# <div class="vector-menu mw-portlet mw-portlet-coll-print_export" id="p-coll-print_export">
# <div class="vector-menu-heading">
# 		Imprimir/exportar
# 	</div>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# <li class="mw-list-item" id="coll-create_a_book"><a href="/w/index.php?title=Especial:Libro&amp;bookcmd=book_creator&amp;referer=Anexo%3AVideojuegos+m%C3%A1s+jugados+por+n%C3%BAmero+de+jugadores"><span>Crear un libro</span></a></li><li class="mw-list-item" id="coll-download-as-rl"><a href="/w/index.php?title=Especial:DownloadAsPdf&amp;page=Anexo%3AVideojuegos_m%C3%A1s_jugados_por_n%C3%BAmero_de_jugadores&amp;action=show-download-screen"><span>Descargar como PDF</span></a></li><li class="mw-list-item" id="t-print"><a accesskey="p" href="/w/index.php?title=Anexo:Videojuegos_m%C3%A1s_jugados_por_n%C3%BAmero_de_jugadores&amp;printable=yes" title="Versión imprimible de esta página [p]"><span>Versión para imprimir</span></a></li>
# </ul>
# </div>
# </div>
# <div class="vector-menu mw-portlet mw-portlet-wikibase-otherprojects emptyPortlet" id="p-wikibase-otherprojects">
# <div class="vector-menu-heading">
# 		En otros proyectos
# 	</div>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </nav>
# </div>
# </div>
# </div>
# <div class="vector-column-end">
# <div class="vector-sticky-pinned-container">
# <nav aria-label="Página de herramientas" class="vector-page-tools-landmark">
# <div class="vector-pinned-container" id="vector-page-tools-pinned-container">
# </div>
# </nav>
# <nav aria-label="Apariencia" class="vector-appearance-landmark">
# <div class="vector-pinned-container" id="vector-appearance-pinned-container">
# <div class="vector-appearance vector-pinnable-element" id="vector-appearance">
# <div class="vector-pinnable-header vector-appearance-pinnable-header vector-pinnable-header-pinned" data-feature-name="appearance-pinned" data-pinnable-element-id="vector-appearance" data-pinned-container-id="vector-appearance-pinned-container" data-unpinned-container-id="vector-appearance-unpinned-container">
# <div class="vector-pinnable-header-label">Apariencia</div>
# <button class="vector-pinnable-header-toggle-button vector-pinnable-header-pin-button" data-event-name="pinnable-header.vector-appearance.pin">mover a la barra lateral</button>
# <button class="vector-pinnable-header-toggle-button vector-pinnable-header-unpin-button" data-event-name="pinnable-header.vector-appearance.unpin">ocultar</button>
# </div>
# </div>
# </div>
# </nav>
# </div>
# </div>
# <div aria-labelledby="firstHeading" class="vector-body" data-mw-ve-target-container="" id="bodyContent">
# <div class="vector-body-before-content">
# <div class="mw-indicators">
# </div>
# <div class="noprint" id="siteSub">De Wikipedia, la enciclopedia libre</div>
# </div>
# <div id="contentSub"><div id="mw-content-subtitle"></div></div>
# <div class="mw-body-content" id="mw-content-text"><div class="mw-content-ltr mw-parser-output" dir="ltr" lang="es"><p>Esta es una lista de los <b>videojuegos más jugados</b> ordenados por su cantidad total de jugadores, incluso por cuentas registradas, suscripciones o propietarios de un videojuego gratuito. En esta lista no se incluyen videojuegos por cifras de ventas oficiales; esos se encuentran en la lista de <a class="mw-redirect" href="/wiki/Videojuegos_m%C3%A1s_vendidos" title="Videojuegos más vendidos">videojuegos más vendidos</a>. Esta lista tampoco es exhaustiva, ya que los conteos de jugadores no siempre están disponibles públicamente, son confiables o están actualizados.
# </p><p>Esta lista no incluye <a href="/wiki/Videojuego_para_m%C3%B3viles" title="Videojuego para móviles">videojuegos móviles</a>, a menos que las versiones del juego también se hayan lanzado en plataformas no móviles. Para la lista de videojuegos móviles véase <a href="/wiki/Anexo:Videojuegos_m%C3%B3viles_m%C3%A1s_jugados_por_n%C3%BAmero_de_jugadores" title="Anexo:Videojuegos móviles más jugados por número de jugadores">Videojuegos móviles más jugados por número de jugadores</a>.
# </p>
# <meta property="mw:PageProp/toc">
# <div class="mw-heading mw-heading2"><h2 id="Lista">Lista</h2><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Anexo:Videojuegos_m%C3%A1s_jugados_por_n%C3%BAmero_de_jugadores&amp;action=edit&amp;section=1" title="Editar sección: Lista"><span>editar</span></a><span class="mw-editsection-bracket">]</span></span></div>
# <table class="wikitable sortable" style="text-align:center;" width="auto">
# <caption>Los videojuegos más jugados por número de jugadores (con al menos 10 millones)
# </caption>
# <tbody><tr>
# <th scope="col">Título
# </th>
# <th scope="col">Número
# </th>
# <th scope="col">A fecha de
# </th>
# <th scope="col">Modelo de negocio
# </th>
# <th scope="col">Fecha de lanzamiento
# </th>
# <th scope="col">Distribuidor(es)
# </th>
# <th class="unsortable"><abbr title="Referencia(s)">Ref.</abbr>
# </th></tr>
# <tr>
# <td><i><a href="/wiki/PUBG:_Battlegrounds" title="PUBG: Battlegrounds">PUBG: Battlegrounds</a></i>
# </td>
# <td>1000 millones <sup class="reference separada" id="cite_ref-movil_1-0"><a href="#cite_note-movil-1"><span class="corchete-llamada">[</span>nota 1<span class="corchete-llamada">]</span></a></sup>​
# </td>
# <td><span style="display:none">02021-03 </span>marzo de 2021
# </td>
# <td><a href="/wiki/Videojuego_gratuito" title="Videojuego gratuito">Gratuito</a>
# </td>
# <td><span style="display:none">02017-12-20 </span>20 de diciembre de 2017
# </td>
# <td><a href="/wiki/Krafton" title="Krafton">Krafton</a> / <a href="/wiki/Tencent" title="Tencent">Tencent</a>
# </td>
# <td><sup class="reference separada" id="cite_ref-2"><a href="#cite_note-2"><span class="corchete-llamada">[</span>1<span class="corchete-llamada">]</span></a></sup>​
# </td></tr>
# <tr>
# <td><i><a href="/wiki/CrossFire_(videojuego)" title="CrossFire (videojuego)">CrossFire</a></i>
# </td>
# <td>1000 millones de cuentas registradas
# </td>
# <td><span style="display:none">02020-02 </span>febrero de 2020
# </td>
# <td>Gratuito
# </td>
# <td><span style="display:none">02007-05-03 </span>3 de mayo de 2007
# </td>
# <td><a class="new" href="/w/index.php?title=Smilegate&amp;action=edit&amp;redlink=1" title="Smilegate (aún no redactado)">Smilegate</a> / <a href="/wiki/Tencent" title="Tencent">Tencent</a>
# </td>
# <td><sup class="reference separada" id="cite_ref-Variety_3-0"><a href="#cite_note-Variety-3"><span class="corchete-llamada">[</span>2<span class="corchete-llamada">]</span></a></sup>​
# </td></tr>
# <tr>
# <td><i><a class="new" href="/w/index.php?title=Dungeon_Fighter_Online&amp;action=edit&amp;redlink=1" title="Dungeon Fighter Online (aún no redactado)">Dungeon Fighter Online</a></i>
# </td>
# <td>700 millones
# </td>
# <td><span style="display:none">02020-05 </span>mayo de 2020
# </td>
# <td>Gratuito
# </td>
# <td><span style="display:none">02005-08 </span>agosto de 2005
# </td>
# <td><a href="/wiki/Nexon_(empresa)" title="Nexon (empresa)">Nexon</a> / <a href="/wiki/Tencent" title="Tencent">Tencent</a>
# </td>
# <td><sup class="reference separada" id="cite_ref-Nexon_4-0"><a href="#cite_note-Nexon-4"><span class="corchete-llamada">[</span>3<span class="corchete-llamada">]</span></a></sup>​
# </td></tr>
# <tr>
# <td><i><a href="/wiki/Garena_Speed_Drifters" title="Garena Speed Drifters">QQ Speed / GKART / Speed Drifters</a></i>
# </td>
# <td>700 millones<sup class="reference separada" id="cite_ref-movil_1-1"><a href="#cite_note-movil-1"><span class="corchete-llamada">[</span>nota 1<span class="corchete-llamada">]</span></a></sup>​
# </td>
# <td><span style="display:none">02020-01 </span>enero de 2020
# </td>
# <td>Gratuito
# </td>
# <td><span style="display:none">02008-01-23 </span>23 de enero de 2008
# </td>
# <td><a href="/wiki/Tencent" title="Tencent">Tencent</a>
# </td>
# <td><sup class="reference separada" id="cite_ref-5"><a href="#cite_note-5"><span class="corchete-llamada">[</span>4<span class="corchete-llamada">]</span></a></sup>​
# </td></tr>
# <tr>
# <td><i><a href="/wiki/Minecraft" title="Minecraft">Minecraft</a></i>
# </td>
# <td>600 millones<sup class="reference separada" id="cite_ref-movil_1-2"><a href="#cite_note-movil-1"><span class="corchete-llamada">[</span>nota 1<span class="corchete-llamada">]</span></a></sup>​
# </td>
# <td><span style="display:none">02020-11 </span>noviembre de 2020
# </td>
# <td>Pagar por jugar
# </td>
# <td><span style="display:none">02009-11-18 </span>18 de noviembre de 2009
# </td>
# <td><a href="/wiki/Mojang_Studios" title="Mojang Studios">Mojang Studios</a>
# </td>
# <td><sup class="reference separada" id="cite_ref-6"><a href="#cite_note-6"><span class="corchete-llamada">[</span>5<span class="corchete-llamada">]</span></a></sup>​
# </td></tr>
# <tr>
# <td><i><a href="/wiki/Pac-Man" title="Pac-Man">Pac-Man Doodle</a></i>
# </td>
# <td>505 millones de usuarios diarios máximos<sup class="reference separada" id="cite_ref-10"><a href="#cite_note-10"><span class="corchete-llamada">[</span>nota 2<span class="corchete-llamada">]</span></a></sup>​<sup class="reference separada" id="cite_ref-movil_1-3"><a href="#cite_note-movil-1"><span class="corchete-llamada">[</span>nota 1<span class="corchete-llamada">]</span></a></sup>​
# </td>
# <td><span style="display:none">02010-06 </span>junio de 2010
# </td>
# <td>Gratuito
# </td>
# <td><span style="display:none">02010-04-21 </span>21 de abril de 2010
# </td>
# <td><a href="/wiki/Namco" title="Namco">Namco</a> / <a href="/wiki/Google" title="Google">Google</a>
# </td>
# <td><sup class="reference separada" id="cite_ref-japantimes_7-1"><a href="#cite_note-japantimes-7"><span class="corchete-llamada">[</span>6<span class="corchete-llamada">]</span></a></sup>​<sup class="reference separada" id="cite_ref-telegraph_8-1"><a href="#cite_note-telegraph-8"><span class="corchete-llamada">[</span>7<span class="corchete-llamada">]</span></a></sup>​
# </td></tr>
# <tr>
# <td><i><a href="/wiki/Among_Us" title="Among Us">Among Us</a></i>
# </td>
# <td>500 millones
# </td>
# <td>noviembre 2020
# </td>
# <td>Pagar por jugar/Gratuito
# </td>
# <td>15 de junio de 2018
# </td>
# <td><a class="mw-redirect" href="/wiki/InnerSloth" title="InnerSloth">Innersloth</a>
# </td>
# <td><sup class="reference separada" id="cite_ref-11"><a href="#cite_note-11"><span class="corchete-llamada">[</span>9<span class="corchete-llamada">]</span></a></sup>​
# </td></tr>
# <tr>
# <td><i><a href="/wiki/Candy_Crush_Saga" title="Candy Crush Saga">Candy Crush Saga</a></i>
# </td>
# <td>500 millones<sup class="reference separada" id="cite_ref-movil_1-4"><a href="#cite_note-movil-1"><span class="corchete-llamada">[</span>nota 1<span class="corchete-llamada">]</span></a></sup>​
# </td>
# <td><span style="display:none">02014-06 </span>junio de 2014
# </td>
# <td>Pagar por jugar/gratuito
# </td>
# <td><span style="display:none">02012-04-12 </span>12 de abril de 2012
# </td>
# <td><a href="/wiki/King_(empresa)" title="King (empresa)">King</a>
# </td>
# <td><sup class="reference separada" id="cite_ref-12"><a href="#cite_note-12"><span class="corchete-llamada">[</span>10<span class="corchete-llamada">]</span></a></sup>​
# </td></tr>
# <tr>
# <td><i><a href="/wiki/Tetris" title="Tetris">Tetris</a></i>
# </td>
# <td>500 millones<sup class="reference separada" id="cite_ref-movil_1-5"><a href="#cite_note-movil-1"><span class="corchete-llamada">[</span>nota 1<span class="corchete-llamada">]</span></a></sup>​
# </td>
# <td><span style="display:none">02016 </span>2016
# </td>
# <td>Pagar por jugar/Gratuito
# </td>
# <td><span style="display:none">01984-06-06 </span>6 de junio de 1984
# </td>
# <td>Varios
# </td>
# <td><sup class="reference separada" id="cite_ref-13"><a href="#cite_note-13"><span class="corchete-llamada">[</span>11<span class="corchete-llamada">]</span></a></sup>​
# </td></tr>
# <tr>
# <td><i><a href="/wiki/Solitario_Microsoft" title="Solitario Microsoft">Solitario Microsoft</a></i>
# </td>
# <td>400 millones
# </td>
# <td><span style="display:none">02015-07 </span>julio de 2015
# </td>
# <td>Gratuito
# </td>
# <td><span style="display:none">01990 </span>1990
# </td>
# <td><a href="/wiki/Microsoft" title="Microsoft">Microsoft</a>
# </td>
# <td><sup class="reference separada" id="cite_ref-14"><a href="#cite_note-14"><span class="corchete-llamada">[</span>12<span class="corchete-llamada">]</span></a></sup>​
# </td></tr>
# <tr>
# <td><i><a class="new" href="/w/index.php?title=Crazyracing_Kartrider&amp;action=edit&amp;redlink=1" title="Crazyracing Kartrider (aún no redactado)">Crazyracing Kartrider</a></i>
# </td>
# <td>380 millones de cuentas registradas
# </td>
# <td>marzo de 2020
# </td>
# <td>Free-to-play
# </td>
# <td><span style="display:none">02004-06-01 </span>1 de junio de 2004
# </td>
# <td><a class="mw-disambig" href="/wiki/Nexon" title="Nexon">Nexon</a>
# </td>
# <td><sup class="reference separada" id="cite_ref-Nexon_4-1"><a href="#cite_note-Nexon-4"><span class="corchete-llamada">[</span>3<span class="corchete-llamada">]</span></a></sup>​
# </td></tr>
# <tr>
# <td><i><a href="/wiki/Fortnite" title="Fortnite">Fortnite</a></i>
# </td>
# <td>350 millones de cuentas registradas<sup class="reference separada" id="cite_ref-movil_1-6"><a href="#cite_note-movil-1"><span class="corchete-llamada">[</span>nota 1<span class="corchete-llamada">]</span></a></sup>​
# </td>
# <td><span style="display:none">02020-04 </span>abril de 2020
# </td>
# <td>Gratuito
# </td>
# <td><span style="display:none">02017-09-26 </span>26 de septiembre de 2017
# </td>
# <td><a href="/wiki/Epic_Games" title="Epic Games">Epic Games</a>
# </td>
# <td><sup class="reference separada" id="cite_ref-15"><a href="#cite_note-15"><span class="corchete-llamada">[</span>13<span class="corchete-llamada">]</span></a></sup>​
# </td></tr>
# <tr>
# <td><i><a class="new" href="/w/index.php?title=Fantasy_Westward_Journey&amp;action=edit&amp;redlink=1" title="Fantasy Westward Journey (aún no redactado)">Fantasy Westward Journey</a></i>
# </td>
# <td>310 millones de cuentas registradas
# </td>
# <td><span style="display:none">02015-04 </span>abril de 2015
# </td>
# <td>Gratuito
# </td>
# <td><span style="display:none">02001-12 </span>diciembre de 2001
# </td>
# <td><a href="/wiki/NetEase" title="NetEase">NetEase</a>
# </td>
# <td><sup class="reference separada" id="cite_ref-16"><a href="#cite_note-16"><span class="corchete-llamada">[</span>14<span class="corchete-llamada">]</span></a></sup>​
# </td></tr>
# <tr>
# <td><i><a href="/wiki/Audition_Online" title="Audition Online">Audition Online</a></i>
# </td>
# <td>300 millones de cuentas registradas
# </td>
# <td><span style="display:none">02010 </span>2010
# </td>
# <td>Gratuito
# </td>
# <td><span style="display:none">02004 </span>2004
# </td>
# <td><a class="new" href="/w/index.php?title=T3_Entertainment&amp;action=edit&amp;redlink=1" title="T3 Entertainment (aún no redactado)">T3 Entertainment</a>
# </td>
# ...
# </li>
# <li id="cite_note-82"><span class="mw-cite-backlink"><a href="#cite_ref-82">↑</a></span> <span class="reference-text"><span class="citation noticia" id="CITAREFMäki17_de_septiembre_de_2018">Mäki, Jonas (17 de septiembre de 2018). <a class="external text" href="https://www.gamereactor.eu/news/694683/Forza+Horizon+3+surpasses+10+million+players/" rel="nofollow">«Forza Horizon 3 surpasses 10 million players»</a>. <i><a href="/wiki/Gamereactor" title="Gamereactor">Gamereactor</a></i><span class="reference-accessdate">. Consultado el 20 de junio de 2020</span>.</span><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rfr_id=info%3Asid%2Fes.wikipedia.org%3AAnexo%3AVideojuegos+m%C3%A1s+jugados+por+n%C3%BAmero+de+jugadores&amp;rft.atitle=Forza+Horizon+3+surpasses+10+million+players&amp;rft.au=M%C3%A4ki%2C+Jonas&amp;rft.aufirst=Jonas&amp;rft.aulast=M%C3%A4ki&amp;rft.date=17+de+septiembre+de+2018&amp;rft.genre=article&amp;rft.jtitle=Gamereactor&amp;rft_id=https%3A%2F%2Fwww.gamereactor.eu%2Fnews%2F694683%2FForza%2BHorizon%2B3%2Bsurpasses%2B10%2Bmillion%2Bplayers%2F&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal"><span style="display:none;"> </span></span></span>
# </li>
# <li id="cite_note-83"><span class="mw-cite-backlink"><a href="#cite_ref-83">↑</a></span> <span class="reference-text"><span class="citation noticia"><a class="external text" href="https://www.vg247.com/2018/06/28/h1z1-10-million-players-ps4-outbreak-map-pc/" rel="nofollow">«H1Z1 PS4 beta has over 10M players, remastered Outbreak map hits PC»</a>. <i><a href="/wiki/VG247" title="VG247">VG247</a></i>. 28 de junio de 2018<span class="reference-accessdate">. Consultado el 20 de junio de 2020</span>.</span><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rfr_id=info%3Asid%2Fes.wikipedia.org%3AAnexo%3AVideojuegos+m%C3%A1s+jugados+por+n%C3%BAmero+de+jugadores&amp;rft.atitle=H1Z1+PS4+beta+has+over+10M+players%2C+remastered+Outbreak+map+hits+PC&amp;rft.date=28+de+junio+de+2018&amp;rft.genre=article&amp;rft.jtitle=VG247&amp;rft_id=https%3A%2F%2Fwww.vg247.com%2F2018%2F06%2F28%2Fh1z1-10-million-players-ps4-outbreak-map-pc%2F&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal"><span style="display:none;"> </span></span></span>
# </li>
# <li id="cite_note-84"><span class="mw-cite-backlink"><a href="#cite_ref-84">↑</a></span> <span class="reference-text"><span class="citation noticia"><a class="external text" href="https://web.archive.org/web/20181223211505/http://www.thexboxhub.com/xbox-one-x-update-ark-survival-evolved-brings-visual-enhancements-galore/" rel="nofollow">«Xbox One X update for ARK: Survival Evolved brings visual enhancements galore!»</a>. <i>TheXboxHub News</i>. 7 de noviembre de 2017. Archivado desde <a class="external text" href="http://www.thexboxhub.com/xbox-one-x-update-ark-survival-evolved-brings-visual-enhancements-galore/" rel="nofollow">el original</a> el 23 de diciembre de 2018<span class="reference-accessdate">. Consultado el 23 de diciembre de 2018</span>.</span><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rfr_id=info%3Asid%2Fes.wikipedia.org%3AAnexo%3AVideojuegos+m%C3%A1s+jugados+por+n%C3%BAmero+de+jugadores&amp;rft.atitle=Xbox+One+X+update+for+ARK%3A+Survival+Evolved+brings+visual+enhancements+galore%21&amp;rft.date=7+de+noviembre+de+2017&amp;rft.genre=article&amp;rft.jtitle=TheXboxHub+News&amp;rft_id=http%3A%2F%2Fwww.thexboxhub.com%2Fxbox-one-x-update-ark-survival-evolved-brings-visual-enhancements-galore%2F&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal"><span style="display:none;"> </span></span></span>
# </li>
# </ol></div>
# <style data-mw-deduplicate="TemplateStyles:r161257576">.mw-parser-output .mw-authority-control{margin-top:1.5em}.mw-parser-output .mw-authority-control .navbox table{margin:0}.mw-parser-output .mw-authority-control .navbox hr:last-child{display:none}.mw-parser-output .mw-authority-control .navbox+.mw-mf-linked-projects{display:none}.mw-parser-output .mw-authority-control .mw-mf-linked-projects{display:flex;padding:0.5em;border:1px solid var(--border-color-base,#a2a9b1);background-color:var(--background-color-neutral,#eaecf0);color:var(--color-base,#202122)}.mw-parser-output .mw-authority-control .mw-mf-linked-projects ul li{margin-bottom:0}.mw-parser-output .mw-authority-control .navbox{border:1px solid var(--border-color-base,#a2a9b1);background-color:var(--background-color-neutral-subtle,#f8f9fa)}.mw-parser-output .mw-authority-control .navbox-list{border-color:#f8f9fa}.mw-parser-output .mw-authority-control .navbox th{background-color:#eeeeff}html.skin-theme-clientpref-night .mw-parser-output .mw-authority-control .mw-mf-linked-projects{border:1px solid var(--border-color-base,#72777d);background-color:var(--background-color-neutral,#27292d);color:var(--color-base,#eaecf0)}html.skin-theme-clientpref-night .mw-parser-output .mw-authority-control .navbox{border:1px solid var(--border-color-base,#72777d)!important;background-color:var(--background-color-neutral-subtle,#202122)!important}html.skin-theme-clientpref-night .mw-parser-output .mw-authority-control .navbox-list{border-color:#202122!important}html.skin-theme-clientpref-night .mw-parser-output .mw-authority-control .navbox th{background-color:#27292d!important}@media(prefers-color-scheme:dark){html.skin-theme-clientpref-os .mw-parser-output .mw-authority-control .mw-mf-linked-projects{border:1px solid var(--border-color-base,#72777d)!important;background-color:var(--background-color-neutral,#27292d)!important;color:var(--color-base,#eaecf0)!important}html.skin-theme-clientpref-os .mw-parser-output .mw-authority-control .navbox{border:1px solid var(--border-color-base,#72777d)!important;background-color:var(--background-color-neutral-subtle,#202122)!important}html.skin-theme-clientpref-os .mw-parser-output .mw-authority-control .navbox-list{border-color:#202122!important}html.skin-theme-clientpref-os .mw-parser-output .mw-authority-control .navbox th{background-color:#27292d!important}}</style><div class="mw-authority-control"><div aria-label="Navbox" class="navbox" role="navigation" style="width: inherit;padding:3px"><table class="hlist navbox-inner" style="border-spacing:0;background:transparent;color:inherit"><tbody><tr><th class="navbox-group" scope="row" style="width: 12%; text-align:center;"><a href="/wiki/Control_de_autoridades" title="Control de autoridades">Control de autoridades</a></th><td class="navbox-list navbox-odd" style="text-align:left;border-left-width:2px;border-left-style:solid;width:100%;padding:0px"><div style="padding:0em 0.25em">
# <ul><li><b>Proyectos Wikimedia</b></li>
# <li><span style="white-space:nowrap;"><span typeof="mw:File"><a href="/wiki/Wikidata" title="Wikidata"><img alt="Wd" class="mw-file-element" data-file-height="590" data-file-width="1050" decoding="async" height="11" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/ff/Wikidata-logo.svg/20px-Wikidata-logo.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/ff/Wikidata-logo.svg/30px-Wikidata-logo.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/ff/Wikidata-logo.svg/40px-Wikidata-logo.svg.png 2x" width="20"/></a></span> Datos:</span> <span class="uid"><a class="extiw" href="https://www.wikidata.org/wiki/Q59296934" title="wikidata:Q59296934">Q59296934</a></span></li></ul>
# </div></td></tr></tbody></table></div><div class="mw-mf-linked-projects hlist">
# <ul><li><span style="white-space:nowrap;"><span typeof="mw:File"><a href="/wiki/Wikidata" title="Wikidata"><img alt="Wd" class="mw-file-element" data-file-height="590" data-file-width="1050" decoding="async" height="11" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/ff/Wikidata-logo.svg/20px-Wikidata-logo.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/ff/Wikidata-logo.svg/30px-Wikidata-logo.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/ff/Wikidata-logo.svg/40px-Wikidata-logo.svg.png 2x" width="20"/></a></span> Datos:</span> <span class="uid"><a class="extiw" href="https://www.wikidata.org/wiki/Q59296934" title="wikidata:Q59296934">Q59296934</a></span></li></ul>
# </div></div>
# <!--
# NewPP limit report
# Parsed by mw‐web.codfw.main‐6c5c9b5484‐k6jtm
# Cached time: 20240923160059
# Cache expiry: 2592000
# Reduced expiry: false
# Complications: [show‐toc]
# CPU time usage: 0.774 seconds
# Real time usage: 0.836 seconds
# Preprocessor visited node count: 28376/1000000
# Post‐expand include size: 188043/2097152 bytes
# Template argument size: 8503/2097152 bytes
# Highest expansion depth: 12/100
# Expensive parser function count: 0/500
# Unstrip recursion depth: 1/20
# Unstrip post‐expand size: 136283/5000000 bytes
# Lua time usage: 0.202/10.000 seconds
# Lua memory usage: 2226001/52428800 bytes
# Number of Wikibase entities loaded: 1/400
# -->
# <!--
# Transclusion expansion time report (%,ms,calls,template)
# 100.00%  680.355      1 -total
#  39.56%  269.168      2 Plantilla:Listaref
#  34.36%  233.774    186 Plantilla:Dts
#  20.10%  136.774     47 Plantilla:Cite_news
#  10.65%   72.454      1 Plantilla:Control_de_autoridades
#   9.98%   67.908    173 Plantilla:Número_mes
#   5.85%   39.785     16 Plantilla:Cite_web
#   3.02%   20.527    173 Plantilla:Nombre_mes
#   2.37%   16.093     77 Plantilla:0expr
#   1.93%   13.146      5 Plantilla:Cite_book
# -->
# <!-- Saved in parser cache with key eswiki:pcache:idhash:8744322-0!canonical and timestamp 20240923160059 and revision id 162114746. Rendering was triggered because: page-view
#  -->
# </meta></div><!--esi <esi:include src="/esitest-fa8a495983347898/content" /> --><noscript><img alt="" height="1" src="https://login.wikimedia.org/wiki/Special:CentralAutoLogin/start?type=1x1" style="border: none; position: absolute;" width="1"/></noscript>
# <div class="printfooter" data-nosnippet="">Obtenido de «<a dir="ltr" href="https://es.wikipedia.org/w/index.php?title=Anexo:Videojuegos_más_jugados_por_número_de_jugadores&amp;oldid=162114746">https://es.wikipedia.org/w/index.php?title=Anexo:Videojuegos_más_jugados_por_número_de_jugadores&amp;oldid=162114746</a>»</div></div>
# <div class="catlinks" data-mw="interface" id="catlinks"><div class="mw-normal-catlinks" id="mw-normal-catlinks"><a href="/wiki/Especial:Categor%C3%ADas" title="Especial:Categorías">Categoría</a>: <ul><li><a href="/wiki/Categor%C3%ADa:Anexos:Videojuegos" title="Categoría:Anexos:Videojuegos">Anexos:Videojuegos</a></li></ul></div><div class="mw-hidden-catlinks mw-hidden-cats-hidden" id="mw-hidden-catlinks">Categoría oculta: <ul><li><a href="/wiki/Categor%C3%ADa:Wikipedia:P%C3%A1ginas_con_errores_de_referencia" title="Categoría:Wikipedia:Páginas con errores de referencia">Wikipedia:Páginas con errores de referencia</a></li></ul></div></div>
# </div>
# </main>
# </div>
# <div class="mw-footer-container">
# <footer class="mw-footer" id="footer">
# <ul id="footer-info">
# <li id="footer-info-lastmod"> Esta página se editó por última vez el 27 ago 2024 a las 20:13.</li>
# <li id="footer-info-copyright">El texto está disponible bajo la <a href="https://es.wikipedia.org/wiki/Wikipedia:Texto_de_la_Licencia_Creative_Commons_Atribuci%C3%B3n-CompartirIgual_4.0_Internacional" rel="license">Licencia Creative Commons Atribución-CompartirIgual 4.0</a><a href="https://creativecommons.org/licenses/by-sa/4.0/deed.es" rel="license" style="display:none;"></a>; pueden aplicarse cláusulas adicionales. Al usar este sitio aceptas nuestros <a href="https://foundation.wikimedia.org/wiki/Policy:Terms_of_Use/es">términos de uso</a> y nuestra <a href="https://foundation.wikimedia.org/wiki/Policy:Privacy_policy/es">política de privacidad</a>.<br/>Wikipedia® es una marca registrada de la <a href="https://wikimediafoundation.org/es/">Fundación Wikimedia</a>, una organización sin ánimo de lucro.</li>
# </ul>
# <ul id="footer-places">
# <li id="footer-places-privacy"><a href="https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Privacy_policy/es">Política de privacidad</a></li>
# <li id="footer-places-about"><a href="/wiki/Wikipedia:Acerca_de">Acerca de Wikipedia</a></li>
# <li id="footer-places-disclaimers"><a href="/wiki/Wikipedia:Limitaci%C3%B3n_general_de_responsabilidad">Limitación de responsabilidad</a></li>
# <li id="footer-places-wm-codeofconduct"><a href="https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Universal_Code_of_Conduct">Código de conducta</a></li>
# <li id="footer-places-developers"><a href="https://developer.wikimedia.org">Desarrolladores</a></li>
# <li id="footer-places-statslink"><a href="https://stats.wikimedia.org/#/es.wikipedia.org">Estadísticas</a></li>
# <li id="footer-places-cookiestatement"><a href="https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Cookie_statement/es">Declaración de cookies</a></li>
# <li id="footer-places-mobileview"><a class="noprint stopMobileRedirectToggle" href="//es.m.wikipedia.org/w/index.php?title=Anexo:Videojuegos_m%C3%A1s_jugados_por_n%C3%BAmero_de_jugadores&amp;mobileaction=toggle_view_mobile">Versión para móviles</a></li>
# </ul>
# <ul class="noprint" id="footer-icons">
# <li id="footer-copyrightico"><a class="cdx-button cdx-button--fake-button cdx-button--size-large cdx-button--fake-button--enabled" href="https://wikimediafoundation.org/"><img alt="Wikimedia Foundation" height="29" loading="lazy" src="/static/images/footer/wikimedia-button.svg" width="84"/></a></li>
# <li id="footer-poweredbyico"><a class="cdx-button cdx-button--fake-button cdx-button--size-large cdx-button--fake-button--enabled" href="https://www.mediawiki.org/"><img alt="Powered by MediaWiki" height="31" loading="lazy" src="/w/resources/assets/poweredby_mediawiki.svg" width="88"/></a></li>
# </ul>
# </footer>
# </div>
# </div>
# </div>
# <div class="vector-settings" id="p-dock-bottom">
# <ul></ul>
# </div><script>(RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgHostname":"mw-web.eqiad.main-6f79cc4fbd-4wtvv","wgBackendResponseTime":135,"wgPageParseReport":{"limitreport":{"cputime":"0.774","walltime":"0.836","ppvisitednodes":{"value":28376,"limit":1000000},"postexpandincludesize":{"value":188043,"limit":2097152},"templateargumentsize":{"value":8503,"limit":2097152},"expansiondepth":{"value":12,"limit":100},"expensivefunctioncount":{"value":0,"limit":500},"unstrip-depth":{"value":1,"limit":20},"unstrip-size":{"value":136283,"limit":5000000},"entityaccesscount":{"value":1,"limit":400},"timingprofile":["100.00%  680.355      1 -total"," 39.56%  269.168      2 Plantilla:Listaref"," 34.36%  233.774    186 Plantilla:Dts"," 20.10%  136.774     47 Plantilla:Cite_news"," 10.65%   72.454      1 Plantilla:Control_de_autoridades","  9.98%   67.908    173 Plantilla:Número_mes","  5.85%   39.785     16 Plantilla:Cite_web","  3.02%   20.527    173 Plantilla:Nombre_mes","  2.37%   16.093     77 Plantilla:0expr","  1.93%   13.146      5 Plantilla:Cite_book"]},"scribunto":{"limitreport-timeusage":{"value":"0.202","limit":"10.000"},"limitreport-memusage":{"value":2226001,"limit":52428800}},"cachereport":{"origin":"mw-web.codfw.main-6c5c9b5484-k6jtm","timestamp":"20240923160059","ttl":2592000,"transientcontent":false}}});});</script>
# </body>
# </html>

# %%
# import requests
# from bs4 import BeautifulSoup

# # URL de la página que contiene la información
# url = 'https://es.wikipedia.org/wiki/Anexo:Videojuegos_m%C3%A1s_jugados_por_n%C3%BAmero_de_jugadores'

# # Hacer una solicitud GET a la URL
# response = requests.get(url)

# # Comprobar que la solicitud fue exitosa (código 200)
# if response.status_code == 200:
#     # Crear el objeto BeautifulSoup
#     soup = BeautifulSoup(response.content, 'html.parser')
    
#     # Buscar la tabla que contiene los datos de los videojuegos
#     table = soup.find('table', {'class': 'wikitable'})
    
#     # Iterar sobre las filas de la tabla (excluyendo la primera fila que es el encabezado)
#     for row in table.find_all('tr')[1:]:
#         # Extraer todas las celdas de la fila
#         cells = row.find_all('td')
        
#         # Verificar que la fila tenga el número correcto de celdas
#         if len(cells) >= 6:
#             # Extraer el contenido de las celdas (ejemplo para un videojuego)
#             game_name = cells[0].get_text(strip=True)  # Nombre del juego
#             copies_sold = cells[1].get_text(strip=True)  # Copias vendidas
#             date = cells[2].get_text(strip=True)  # Fecha
#             model = cells[3].get_text(strip=True)  # Modelo (gratis o pago)
#             release_date = cells[4].get_text(strip=True)  # Fecha de lanzamiento
#             company = cells[5].get_text(strip=True)  # Empresa
            
#             # Mostrar los resultados
#             print(f"Nombre: {game_name}")
#             print(f"Copias vendidas: {copies_sold}")
#             print(f"Fecha: {date}")
#             print(f"Modelo: {model}")
#             print(f"Fecha de lanzamiento: {release_date}")
#             print(f"Compañía: {company}")
#             print("---------------------------------------------------")
# else:
#     print(f"Error al acceder a la página: {response.status_code}")
# Out:
# Nombre: PUBG: Battlegrounds
# Copias vendidas: 1000 millones[nota 1]​
# Fecha: 02021-03marzo de 2021
# Modelo: Gratuito
# Fecha de lanzamiento: 02017-12-2020 de diciembre de 2017
# Compañía: Krafton/Tencent
# ---------------------------------------------------
# Nombre: CrossFire
# Copias vendidas: 1000 millones de cuentas registradas
# Fecha: 02020-02febrero de 2020
# Modelo: Gratuito
# Fecha de lanzamiento: 02007-05-033 de mayo de 2007
# Compañía: Smilegate/Tencent
# ---------------------------------------------------
# Nombre: Dungeon Fighter Online
# Copias vendidas: 700 millones
# Fecha: 02020-05mayo de 2020
# Modelo: Gratuito
# Fecha de lanzamiento: 02005-08agosto de 2005
# Compañía: Nexon/Tencent
# ---------------------------------------------------
# Nombre: QQ Speed / GKART / Speed Drifters
# Copias vendidas: 700 millones[nota 1]​
# Fecha: 02020-01enero de 2020
# Modelo: Gratuito
# Fecha de lanzamiento: 02008-01-2323 de enero de 2008
# Compañía: Tencent
# ---------------------------------------------------
# Nombre: Minecraft
# Copias vendidas: 600 millones[nota 1]​
# Fecha: 02020-11noviembre de 2020
# Modelo: Pagar por jugar
# Fecha de lanzamiento: 02009-11-1818 de noviembre de 2009
# Compañía: Mojang Studios
# ---------------------------------------------------
# Nombre: Pac-Man Doodle
# Copias vendidas: 505 millones de usuarios diarios máximos[nota 2]​[nota 1]​
# Fecha: 02010-06junio de 2010
# Modelo: Gratuito
# Fecha de lanzamiento: 02010-04-2121 de abril de 2010
# Compañía: Namco/Google
# ---------------------------------------------------
# Nombre: Among Us
# Copias vendidas: 500 millones
# Fecha: noviembre 2020
# Modelo: Pagar por jugar/Gratuito
# Fecha de lanzamiento: 15 de junio de 2018
# Compañía: Innersloth
# ---------------------------------------------------
# Nombre: Candy Crush Saga
# Copias vendidas: 500 millones[nota 1]​
# Fecha: 02014-06junio de 2014
# Modelo: Pagar por jugar/gratuito
# Fecha de lanzamiento: 02012-04-1212 de abril de 2012
# Compañía: King
# ---------------------------------------------------
# Nombre: Tetris
# Copias vendidas: 500 millones[nota 1]​
# Fecha: 020162016
# Modelo: Pagar por jugar/Gratuito
# Fecha de lanzamiento: 01984-06-066 de junio de 1984
# Compañía: Varios
# ---------------------------------------------------
# Nombre: Solitario Microsoft
# Copias vendidas: 400 millones
# Fecha: 02015-07julio de 2015
# Modelo: Gratuito
# Fecha de lanzamiento: 019901990
# Compañía: Microsoft
# ---------------------------------------------------
# Nombre: Crazyracing Kartrider
# Copias vendidas: 380 millones de cuentas registradas
# Fecha: marzo de 2020
# Modelo: Free-to-play
# Fecha de lanzamiento: 02004-06-011 de junio de 2004
# Compañía: Nexon
# ---------------------------------------------------
# Nombre: Fortnite
# Copias vendidas: 350 millones de cuentas registradas[nota 1]​
# Fecha: 02020-04abril de 2020
# Modelo: Gratuito
# Fecha de lanzamiento: 02017-09-2626 de septiembre de 2017
# Compañía: Epic Games
# ---------------------------------------------------
# Nombre: Fantasy Westward Journey
# Copias vendidas: 310 millones de cuentas registradas
# Fecha: 02015-04abril de 2015
# Modelo: Gratuito
# Fecha de lanzamiento: 02001-12diciembre de 2001
# Compañía: NetEase
# ---------------------------------------------------
# Nombre: Audition Online
# Copias vendidas: 300 millones de cuentas registradas
# Fecha: 020102010
# Modelo: Gratuito
# Fecha de lanzamiento: 020042004
# Compañía: T3 Entertainment
# ---------------------------------------------------
# Nombre: Animal Jam
# Copias vendidas: 301,6 millones
# Fecha: 02020-06junio de 2020
# Modelo: Gratuito
# Fecha de lanzamiento: 02010-09septiembre de 2010
# Compañía: Wildworks
# ---------------------------------------------------
# Nombre: RuneScape
# Copias vendidas: 282,1 millones de cuentas registradas
# Fecha: 02020-06junio de 2020
# Modelo: Suscripción/Gratuito
# Fecha de lanzamiento: 02001-01-044 de enero de 2001
# Compañía: Jagex
# ---------------------------------------------------
# Nombre: Rules of Survival
# Copias vendidas: 280 millones[nota 1]​
# Fecha: 02020-06junio de 2020
# Modelo: Gratuito
# Fecha de lanzamiento: 02017-11-1717 de noviembre de 2017
# Compañía: NetEase
# ---------------------------------------------------
# Nombre: Roblox
# Copias vendidas: 202 millones de jugadores mensuales
# Fecha: abril 2021
# Modelo: Gratuito
# Fecha de lanzamiento: 02006-08-2727 de agosto de 2006
# Compañía: Roblox Corporation
# ---------------------------------------------------
# Nombre: Dragon Nest
# Copias vendidas: 200 millones
# Fecha: 02013-03marzo de 2013
# Modelo: Gratuito
# Fecha de lanzamiento: 02010-03marzo de 2010
# Compañía: Nexon
# ---------------------------------------------------
# Nombre: World of Tanks
# Copias vendidas: 160 millones
# Fecha: 02020-04abril de 2020
# Modelo: Gratuito
# Fecha de lanzamiento: 02010-08-1212 de agosto de 2010
# Compañía: Wargaming
# ---------------------------------------------------
# Nombre: Chess.com
# Copias vendidas: 150 millones
# Fecha: 02023-10octubre de 2023
# Modelo: Gratuito
# Fecha de lanzamiento: 02007-05mayo de 2007
# Compañía:
# ---------------------------------------------------
# Nombre: The Legend of Mir 3
# Copias vendidas: 120 millones de cuentas registradas
# Fecha: 02012-02febrero de 2012
# Modelo: Suscripción/Gratuito
# Fecha de lanzamiento: 02004-10octubre de 2004
# Compañía: WeMade Entertainment
# ---------------------------------------------------
# Nombre: League of Legends
# Copias vendidas: 101 millones de jugadores mensuales máximos
# Fecha: 02018-08agosto de 2018
# Modelo: Gratuito
# Fecha de lanzamiento: 02009-10-2727 de octubre de 2009
# Compañía: Riot Games
# ---------------------------------------------------
# Nombre: Call of Duty: Warzone
# Copias vendidas: 100 millones[nota 3]​
# Fecha: 02021-04abril de 2021
# Modelo: Gratuito
# Fecha de lanzamiento: 02020-03-2020 de marzo de 2020
# Compañía: Activision Blizzard
# ---------------------------------------------------
# Nombre: World of Warcraft
# Copias vendidas: 100 millones de cuentas registradas
# Fecha: 02014-01enero de 2014
# Modelo: Suscripción/Pagar por jugar[nota 4]​
# Fecha de lanzamiento: 02004-11-2323 de noviembre de 2004
# Compañía: Blizzard Entertainment
# ---------------------------------------------------
# Nombre: Apex Legends
# Copias vendidas: 100 millones
# Fecha: 02021-04abril de 2021
# Modelo: Gratuito
# Fecha de lanzamiento: 02019-02-044 de febrero de 2019
# Compañía: Electronic Arts
# ---------------------------------------------------
# Nombre: CityVille
# Copias vendidas: 100 millones[nota 1]​
# Fecha: 02011-10octubre de 2011
# Modelo: Gratuito
# Fecha de lanzamiento: 02010-12-022 de diciembre de 2010
# Compañía: Zynga
# ---------------------------------------------------
# Nombre: Happy Farm
# Copias vendidas: 100 millones[nota 1]​
# Fecha: 02013-08agosto de 2013
# Modelo: Gratuito
# Fecha de lanzamiento: 02008-11noviembre de 2008
# Compañía: 5 minutes
# ---------------------------------------------------
# Nombre: MapleStory
# Copias vendidas: 100 millones de cuentas registradas
# Fecha: 02018-04abril de 2018
# Modelo: Gratuito
# Fecha de lanzamiento: 02007-04-2929 de abril de 2007
# Compañía: Nexon
# ---------------------------------------------------
# Nombre: Scions of Fate
# Copias vendidas: 100 millones de cuentas registradas
# Fecha: 02018-04abril de 2018
# Modelo: Gratuito
# Fecha de lanzamiento: 02004-11-2424 de noviembre de 2004
# Compañía: KRG Soft
# ---------------------------------------------------
# Nombre: The Sims Social
# Copias vendidas: 100 millones[nota 1]​
# Fecha: 02011-10octubre de 2011
# Modelo: Gratuito
# Fecha de lanzamiento: 02011-08-099 de agosto de 2011
# Compañía: Electronic Arts
# ---------------------------------------------------
# Nombre: Zhengtu
# Copias vendidas: 100 millones de cuentas registradas
# Fecha: 02018-04abril de 2018
# Modelo: Gratuito
# Fecha de lanzamiento: 020072007
# Compañía: Zhengtu Network
# ---------------------------------------------------
# Nombre: Microsoft Solitaire Collection
# Copias vendidas: 100 millones
# Fecha: 02016-08agosto de 2016
# Modelo: Gratuito
# Fecha de lanzamiento: 02015-07-2929 de julio de 2015
# Compañía: Microsoft
# ---------------------------------------------------
# Nombre: Hearthstone
# Copias vendidas: 100 millones
# Fecha: 02018-11noviembre de 2018
# Modelo: Gratuito
# Fecha de lanzamiento: 02014-03-1111 de marzo de 2014
# Compañía: Blizzard Entertainment
# ---------------------------------------------------
# Nombre: OGame
# Copias vendidas: 100 millones de cuentas registradas
# Fecha: 020182018
# Modelo: Gratuito
# Fecha de lanzamiento: 020022002
# Compañía: Gameforge
# ---------------------------------------------------
# Nombre: FarmVille
# Copias vendidas: 83 millones de jugadores mensuales máximos[nota 1]​
# Fecha: 02010-03marzo de 2010
# Modelo: Gratuito
# Fecha de lanzamiento: 02009-06-1919 de junio de 2009
# Compañía: Zynga
# ---------------------------------------------------
# Nombre: Westward Journey Online II
# Copias vendidas: 83 millones de cuentas registradas
# Fecha: 02006-11noviembre de 2006
# Modelo: Gratuito
# Fecha de lanzamiento: 020012001
# Compañía: NetEase
# ---------------------------------------------------
# Nombre: Ragnarok Online
# Copias vendidas: 80 millones de cuentas registradas
# Fecha: 02018-04abril de 2018
# Modelo: Suscripción[nota 5]​
# Fecha de lanzamiento: 02002-08-3131 de agosto de 2002
# Compañía: Gravity
# ---------------------------------------------------
# Nombre: Moshi Monsters
# Copias vendidas: 80 millones de cuentas registradas
# Fecha: 02014-07julio de 2014
# Modelo: Gratuito
# Fecha de lanzamiento: 02008-04-1616 de abril de 2008
# Compañía: Mind Candy
# ---------------------------------------------------
# Nombre: Yu-Gi-Oh! Duel Links
# Copias vendidas: 80 millones[nota 1]​
# Fecha: 02019-10octubre de 2019
# Modelo: Gratuito
# Fecha de lanzamiento: 02016-11-1717 de noviembre de 2016
# Compañía: Konami
# ---------------------------------------------------
# Nombre: Dragon Oath
# Copias vendidas: 75 millones de cuentas registradas
# Fecha: 02010-02febrero de 2010
# Modelo: Gratuito
# Fecha de lanzamiento: 020072007
# Compañía: KRG Soft
# ---------------------------------------------------
# Nombre: Dofus
# Copias vendidas: 62 millones de cuentas registradas
# Fecha: 02018-04abril de 2018
# Modelo: Suscripción[nota 5]​
# Fecha de lanzamiento: 02004-09septiembre de 2004
# Compañía: Ankama
# ---------------------------------------------------
# Nombre: Overwatch
# Copias vendidas: 60 millones
# Fecha: 02021-04abril de 2021
# Modelo: Pagar por jugar
# Fecha de lanzamiento: 02016-05-2424 de mayo de 2016
# Compañía: Blizzard Entertainment
# ---------------------------------------------------
# Nombre: Flyff
# Copias vendidas: 60 millones de cuentas registradas
# Fecha: 02018-04abril de 2018
# Modelo: Gratuito
# Fecha de lanzamiento: 02004-08-1616 de agosto de 2004
# Compañía: Gala Lab
# ---------------------------------------------------
# Nombre: Rocket League
# Copias vendidas: 58 millones
# Fecha: 02019-06junio de 2019
# Modelo: Gratuito
# Fecha de lanzamiento: 02015-07-077 de julio de 2015
# Compañía: Psyonix
# ---------------------------------------------------
# Nombre: Mu Online
# Copias vendidas: 56 millones
# Fecha: 020092009
# Modelo: Gratuito
# Fecha de lanzamiento: 02003-10-066 de octubre de 2003
# Compañía: Webzen
# ---------------------------------------------------
# Nombre: Lineage
# Copias vendidas: 50 millones
# Fecha: 02007-03marzo de 2007
# Modelo: Suscripción
# Fecha de lanzamiento: 01998-09-033 de septiembre de 1998
# Compañía: NCSoft
# ---------------------------------------------------
# Nombre: Perfect World
# Copias vendidas: 50 millones de cuentas registradas
# Fecha: 02018-04abril de 2018
# Modelo: Gratuito
# Fecha de lanzamiento: 02005-07julio de 2005
# Compañía: Beijing Perfect World
# ---------------------------------------------------
# Nombre: Team Fortress 2
# Copias vendidas: 50 millones de propietarios enSteam[nota 6]​
# Fecha: 02018-07julio de 2018
# Modelo: Gratuito
# Fecha de lanzamiento: 02007-10-1010 de octubre de 2007
# Compañía: Valve Corporation
# ---------------------------------------------------
# Nombre: Tom Clancy's Rainbow Six: Siege
# Copias vendidas: 50 millones de cuentas registradas
# Fecha: 02019-09septiembre de 2019
# Modelo: Pagar por jugar
# Fecha de lanzamiento: 02015-12-011 de diciembre de 2015
# Compañía: Ubisoft
# ---------------------------------------------------
# Nombre: Warframe
# Copias vendidas: 50 millones de cuentas registradas
# Fecha: 02019-03marzo de 2019
# Modelo: Gratuito
# Fecha de lanzamiento: 02013-03-2525 de marzo de 2013
# Compañía: Digital Extremes
# ---------------------------------------------------
# Nombre: Counter-Strike: Global Offensive
# Copias vendidas: 46 millones de propietarios en Steam[nota 6]​
# Fecha: 02018-07julio de 2018
# Modelo: Gratuito
# Fecha de lanzamiento: 02012-08-2121 de agosto de 2012
# Compañía: Valve Corporation
# ---------------------------------------------------
# Nombre: FarmVille 2
# Copias vendidas: 43 millones de jugadores mensuales máximos[nota 1]​
# Fecha: 02012-12diciembre de 2012
# Modelo: Gratuito
# Fecha de lanzamiento: 02012-09septiembre de 2012
# Compañía: Zynga
# ---------------------------------------------------
# Nombre: Dota 2
# Copias vendidas: 42,9 millones
# Fecha: 02015-02febrero de 2015
# Modelo: Gratuito
# Fecha de lanzamiento: 02013-07-099 de julio de 2013
# Compañía: Valve Corporation
# ---------------------------------------------------
# Nombre: Drakensang Online
# Copias vendidas: 35 millones de cuentas registradas
# Fecha: 02018-04abril de 2018
# Modelo: Gratuito
# Fecha de lanzamiento: 02011-08agosto de 2011
# Compañía: Bigpoint
# ---------------------------------------------------
# Nombre: Teamfight Tactics
# Copias vendidas: 33 millones de jugadores mensuales
# Fecha: 02019-09septiembre de 2019
# Modelo: Gratuito
# Fecha de lanzamiento: 02019-06-2626 de junio de 2019
# Compañía: Riot Games
# ---------------------------------------------------
# Nombre: Grand Theft Auto Online
# Copias vendidas: 34 millones
# Fecha: 02014-11noviembre de 2014
# Modelo: Pagar por jugar
# Fecha de lanzamiento: 02013-10-011 de octubre de 2013
# Compañía: Rockstar Games
# ---------------------------------------------------
# Nombre: Evony
# Copias vendidas: 33 millones de cuentas registradas
# Fecha: 02016-10octubre de 2016
# Modelo: Gratuito
# Fecha de lanzamiento: 02009-04-066 de abril de 2009
# Compañía: Evony LLC
# ---------------------------------------------------
# Nombre: FIFA 18
# Copias vendidas: 32,5 million[nota 7]​
# Fecha: 02018-12diciembre de 2018
# Modelo: Pagar por jugar
# Fecha de lanzamiento: 02017-09-2929 de septiembre de 2017
# Compañía: EA Sports
# ---------------------------------------------------
# Nombre: Pac-Man
# Copias vendidas: 30 millones de jugadores mensuales de Estados Unidos
# Fecha: 019821982
# Modelo: Pagar por jugar
# Fecha de lanzamiento: 01980-04-2121 de abril de 1980
# Compañía: Namco
# ---------------------------------------------------
# Nombre: Black Desert Online
# Copias vendidas: 30 millones[nota 1]​
# Fecha: 02020-01enero de 2020
# Modelo: Pagar por jugar
# Fecha de lanzamiento: 02015-07-1414 de julio de 2015
# Compañía: Kakao Games
# ---------------------------------------------------
# Nombre: FIFA 17
# Copias vendidas: 30 millones[nota 7]​
# Fecha: 02018-12diciembre de 2018
# Modelo: Pagar por jugar
# Fecha de lanzamiento: 02016-09-2727 de septiembre de 2016
# Compañía: EA Sports
# ---------------------------------------------------
# Nombre: FIFA 16
# Copias vendidas: 28.3 millones[nota 7]​
# Fecha: 02018-12diciembre de 2018
# Modelo: Pagar por jugar
# Fecha de lanzamiento: 02015-09-2222 de septiembre de 2015
# Compañía: EA Sports
# ---------------------------------------------------
# Nombre: GetAmped
# Copias vendidas: 26 millones de cuentas registradas
# Fecha: 02008-10octubre de 2008
# Modelo: Gratuito
# Fecha de lanzamiento: 02002-04-2626 de abril de 2002
# Compañía: CyberStep
# ---------------------------------------------------
# Nombre: Metal Slug Defense
# Copias vendidas: 29 millones[nota 1]​
# Fecha: 02016-02febrero de 2016
# Modelo: Gratuito
# Fecha de lanzamiento: 02014-04-011 de abril de 2014
# Compañía: SNK
# ---------------------------------------------------
# Nombre: Unturned
# Copias vendidas: 27 millones de propietarios en Steam[nota 6]​
# Fecha: 02018-07julio de 2018
# Modelo: Gratuito
# Fecha de lanzamiento: 02017-07-077 de julio de 2017
# Compañía: Smartly Dressed Games
# ---------------------------------------------------
# Nombre: TERA
# Copias vendidas: 26 millones de cuentas registradas
# Fecha: 02017-05mayo de 2017
# Modelo: Suscripción/Gratuito
# Fecha de lanzamiento: 02011-01-2525 de enero de 2011
# Compañía: Bluehole
# ---------------------------------------------------
# Nombre: Street Fighter II
# Copias vendidas: 25 millones de jugadores totales de Estados Unidos
# Fecha: 019941994
# Modelo: Pagar por jugar
# Fecha de lanzamiento: 01991-02-066 de febrero de 1991
# Compañía: Capcom
# ---------------------------------------------------
# Nombre: Call of Duty: WWII
# Copias vendidas: 24,9 millones[nota 7]​
# Fecha: 02018-12diciembre de 2018
# Modelo: Pagar por jugar
# Fecha de lanzamiento: 02017-11-033 de noviembre de 2017
# Compañía: Activision
# ---------------------------------------------------
# Nombre: Left 4 Dead 2
# Copias vendidas: 23 millones de propietarios en Steam[nota 6]​
# Fecha: 02018-07julio de 2018
# Modelo: Pagar por jugar
# Fecha de lanzamiento: 02009-11-1717 de noviembre de 2009
# Compañía: Valve Corporation
# ---------------------------------------------------
# Nombre: DC Universe Online
# Copias vendidas: 20 millones
# Fecha: 02015-05mayo de 2015
# Modelo: Gratuito
# Fecha de lanzamiento: 02011-01-1111 de enero de 2011
# Compañía: Daybreak Game Company
# ---------------------------------------------------
# Nombre: Shadowverse
# Copias vendidas: 20 millones[nota 1]​
# Fecha: 02018-10octubre de 2018
# Modelo: Gratuito
# Fecha de lanzamiento: 02016-06-1717 de junio de 2016
# Compañía: Cygames/NetEase
# ---------------------------------------------------
# Nombre: Blade & Soul
# Copias vendidas: 18 millones
# Fecha: 02013-12diciembre de 2013
# Modelo: Suscripción[nota 5]​
# Fecha de lanzamiento: 02012-06-3030 de junio de 2012
# Compañía: NCSoft
# ---------------------------------------------------
# Nombre: Final Fantasy XIV
# Copias vendidas: 18 millones de cuentas registradas
# Fecha: 02019-12diciembre de 2019
# Modelo: Suscripción
# Fecha de lanzamiento: 02013-08-2727 de agosto de 2013
# Compañía: Square Enix
# ---------------------------------------------------
# Nombre: Payday 2
# Copias vendidas: 18 millones de propietarios en Steam[nota 6]​
# Fecha: 02018-07julio de 2018
# Modelo: Pagar por jugar
# Fecha de lanzamiento: 02013-08-1313 de agosto de 2013
# Compañía: Starbreeze Studios
# ---------------------------------------------------
# Nombre: Farm Town
# Copias vendidas: 17 millones de jugadores mensuales máximos[nota 1]​
# Fecha: 02009-08agosto de 2009
# Modelo: Gratuito
# Fecha de lanzamiento: 02009-02-011 de febrero de 2009
# Compañía: SlashKey
# ---------------------------------------------------
# Nombre: The Last of Us Remastered
# Copias vendidas: 15,9 millones[nota 7]​
# Fecha: 02018-12diciembre de 2018
# Modelo: Pagar por jugar
# Fecha de lanzamiento: 02014-07-2929 de julio de 2014
# Compañía: Sony
# ---------------------------------------------------
# Nombre: osu!
# Copias vendidas: 15,2 millones de cuentas registradas
# Fecha: 02020-06junio de 2020
# Modelo: Gratuito
# Fecha de lanzamiento: 02007-09-1616 de septiembre de 2007
# Compañía: ppy
# ---------------------------------------------------
# Nombre: Doom
# Copias vendidas: 15 millones
# Fecha: 020062006
# Modelo: Shareware
# Fecha de lanzamiento: 01993-12-1010 de diciembre de 1993
# Compañía: id Software
# ---------------------------------------------------
# Nombre: For Honor
# Copias vendidas: 15 millones
# Fecha: 02018-10octubre de 2018
# Modelo: Gratuito
# Fecha de lanzamiento: 02017-02-1414 de febrero de 2017
# Compañía: Ubisoft
# ---------------------------------------------------
# Nombre: Trove
# Copias vendidas: 15 millones
# Fecha: 02018-02febrero de 2018
# Modelo: Gratuito
# Fecha de lanzamiento: 02015-07-099 de julio de 2015
# Compañía: Trion Worlds
# ---------------------------------------------------
# Nombre: Puyopuyo!! Quest Arcade
# Copias vendidas: 15 millones
# Fecha: 02016-07julio de 2016
# Modelo: Gratuito
# Fecha de lanzamiento: 02013-11-077 de noviembre de 2013
# Compañía: Sega
# ---------------------------------------------------
# Nombre: Lineage II
# Copias vendidas: 14 millones
# Fecha: 02007-06junio de 2007
# Modelo: Gratuito
# Fecha de lanzamiento: 02003-10-011 de octubre de 2003
# Compañía: NCSoft
# ---------------------------------------------------
# Nombre: Paladins
# Copias vendidas: 14 millones de propietarios en Steam[nota 6]​
# Fecha: 02018-07julio de 2018
# Modelo: Gratuito
# Fecha de lanzamiento: 02016-09-1515 de septiembre de 2016
# Compañía: Hi-Rez Studios
# ---------------------------------------------------
# Nombre: Battlefield 4
# Copias vendidas: 13,9 millones[nota 7]​
# Fecha: 02018-12diciembre de 2018
# Modelo: Pagar por jugar
# Fecha de lanzamiento: 02013-10-2929 de octubre de 2013
# Compañía: Electronic Arts
# ---------------------------------------------------
# Nombre: The Elder Scrolls Online
# Copias vendidas: 13,5 millones de cuentas registradas
# Fecha: 02017-12diciembre de 2017
# Modelo: Pagar por jugar
# Fecha de lanzamiento: 02014-04-044 de abril de 2014
# Compañía: Bethesda Softworks
# ---------------------------------------------------
# Nombre: Call of Duty: Ghosts
# Copias vendidas: 12,6 millones[nota 7]​
# Fecha: 02018-12diciembre de 2018
# Modelo: Pagar por jugar
# Fecha de lanzamiento: 02013-11-055 de noviembre de 2013
# Compañía: Activision
# ---------------------------------------------------
# Nombre: FIFA 19
# Copias vendidas: 12,5 millones[nota 7]​
# Fecha: 02018-12diciembre de 2018
# Modelo: Pagar por jugar
# Fecha de lanzamiento: 02018-09-2828 de septiembre de 2018
# Compañía: EA Sports
# ---------------------------------------------------
# Nombre: Guild Wars 2
# Copias vendidas: 11 millones
# Fecha: 02018-09septiembre de 2018
# Modelo: Gratuito
# Fecha de lanzamiento: 02012-08-2828 de agosto de 2012
# Compañía: NCSoft
# ---------------------------------------------------
# Nombre: Forza Horizon 3
# Copias vendidas: 10 millones
# Fecha: 02018-09septiembre de 2018
# Modelo: Pagar por jugar
# Fecha de lanzamiento: 02016-09-2727 de septiembre de 2016
# Compañía: Microsoft Studios
# ---------------------------------------------------
# Nombre: Star Wars: The Old Republic
# Copias vendidas: 10 millones de cuentas registradas
# Fecha: 02018-04abril de 2018
# Modelo: Suscripción
# Fecha de lanzamiento: 02011-12-2020 de diciembre de 2011
# Compañía: Electronic Arts
# ---------------------------------------------------
# Nombre: Free Realms
# Copias vendidas: 10 millones de cuentas registradas
# Fecha: 02018-04abril de 2018
# Modelo: Gratuito
# Fecha de lanzamiento: 02009-04-2828 de abril de 2009
# Compañía: Sony Online Entertainment
# ---------------------------------------------------
# Nombre: H1Z1
# Copias vendidas: 10 millones
# Fecha: 02018-06junio de 2018
# Modelo: Gratuito
# Fecha de lanzamiento: 02018-02-2828 de febrero de 2018
# Compañía: Daybreak Game Company
# ---------------------------------------------------
# Nombre: Robocraft
# Copias vendidas: 10 millones de propietarios en Steam[nota 6]​
# Fecha: 02018-07julio de 2018
# Modelo: Gratuito
# Fecha de lanzamiento: 02017-08-2424 de agosto de 2017
# Compañía: Freejam Games
# ---------------------------------------------------
# Nombre: Ark: Survival Evolved
# Copias vendidas: 10  millones[nota 1]​
# Fecha: 02017-11noviembre de 2017
# Modelo: Pagar por jugar
# Fecha de lanzamiento: 02017-08-2929 de agosto de 2017
# Compañía: Studio Wildcard
# ---------------------------------------------------

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Realizamos la solicitud a la página web
url = 'https://es.wikipedia.org/wiki/Anexo:Videojuegos_m%C3%A1s_jugados_por_n%C3%BAmero_de_jugadores'
response = requests.get(url)

# Parseamos el contenido HTML
soup = BeautifulSoup(response.text, 'html.parser')

# Extraemos los datos (por ejemplo, de una tabla)
# Aquí debes ajustar los selectores según la estructura HTML de la página
# Por ejemplo, si quieres extraer de una tabla:
table = soup.find('table')  # Encuentra la tabla, ajusta el selector según tu necesidad
rows = table.find_all('tr')  # Extrae todas las filas de la tabla

# Preparamos una lista para almacenar los datos
data = []
columns = []

# Extraemos los encabezados de la tabla
header = rows[0]
for th in header.find_all('th'):
    columns.append(th.text.strip())  # Guardamos los nombres de las columnas

# Extraemos los datos fila por fila
for row in rows[1:]:  # Excluimos la primera fila porque contiene los encabezados
    cells = row.find_all('td')
    data.append([cell.text.strip() for cell in cells])  # Extraemos los datos de cada celda

# Creamos un DataFrame con los datos extraídos
df = pd.DataFrame(data, columns=columns)

# Mostramos el DataFrame
print(df)
# Out:
#                                Título  \
# 0                 PUBG: Battlegrounds
# 1                           CrossFire
# 2              Dungeon Fighter Online
# 3   QQ Speed / GKART / Speed Drifters
# 4                           Minecraft
# ..                                ...
# 90        Star Wars: The Old Republic
# 91                        Free Realms
# 92                               H1Z1
# 93                          Robocraft
# 94              Ark: Survival Evolved
#
#                                            Número                  A fecha de  \
# 0                         1000 millones [nota 1]​      02021-03 marzo de 2021
# 1            1000 millones de cuentas registradas    02020-02 febrero de 2020
# 2                                    700 millones       02020-05 mayo de 2020
# 3                           700 millones[nota 1]​      02020-01 enero de 2020
# 4                           600 millones[nota 1]​  02020-11 noviembre de 2020
# ..                                            ...                         ...
# 90             10 millones de cuentas registradas      02018-04 abril de 2018
# 91             10 millones de cuentas registradas      02018-04 abril de 2018
# 92                                    10 millones      02018-06 junio de 2018
# 93  10 millones de propietarios en Steam[nota 6]​      02018-07 julio de 2018
# 94                          10  millones[nota 1]​  02017-11 noviembre de 2017
#
#    Modelo de negocio                 Fecha de lanzamiento  \
# 0           Gratuito  02017-12-20 20 de diciembre de 2017
# 1           Gratuito        02007-05-03 3 de mayo de 2007
# 2           Gratuito              02005-08 agosto de 2005
# 3           Gratuito      02008-01-23 23 de enero de 2008
# 4    Pagar por jugar  02009-11-18 18 de noviembre de 2009
# ..               ...                                  ...
# 90       Suscripción  02011-12-20 20 de diciembre de 2011
# 91          Gratuito      02009-04-28 28 de abril de 2009
# 92          Gratuito    02018-02-28 28 de febrero de 2018
# 93          Gratuito     02017-08-24 24 de agosto de 2017
# 94   Pagar por jugar     02017-08-29 29 de agosto de 2017
#
#              Distribuidor(es)   Ref.
# 0           Krafton / Tencent   [1]​
# 1         Smilegate / Tencent   [2]​
# 2             Nexon / Tencent   [3]​
# 3                     Tencent   [4]​
# 4              Mojang Studios   [5]​
# ..                        ...    ...
# 90            Electronic Arts  [31]​
# 91  Sony Online Entertainment  [31]​
# 92      Daybreak Game Company  [76]​
# 93              Freejam Games  [45]​
# 94            Studio Wildcard  [77]​
#
# [95 rows x 7 columns]

# %%
df
# Out:
#                                Título  \
# 0                 PUBG: Battlegrounds
# 1                           CrossFire
# 2              Dungeon Fighter Online
# 3   QQ Speed / GKART / Speed Drifters
# 4                           Minecraft
# ..                                ...
# 90        Star Wars: The Old Republic
# 91                        Free Realms
# 92                               H1Z1
# 93                          Robocraft
# 94              Ark: Survival Evolved
#
#                                            Número                  A fecha de  \
# 0                         1000 millones [nota 1]​      02021-03 marzo de 2021
# 1            1000 millones de cuentas registradas    02020-02 febrero de 2020
# 2                                    700 millones       02020-05 mayo de 2020
# 3                           700 millones[nota 1]​      02020-01 enero de 2020
# 4                           600 millones[nota 1]​  02020-11 noviembre de 2020
# ..                                            ...                         ...
# 90             10 millones de cuentas registradas      02018-04 abril de 2018
# 91             10 millones de cuentas registradas      02018-04 abril de 2018
# 92                                    10 millones      02018-06 junio de 2018
# 93  10 millones de propietarios en Steam[nota 6]​      02018-07 julio de 2018
# 94                          10  millones[nota 1]​  02017-11 noviembre de 2017
#
#    Modelo de negocio                 Fecha de lanzamiento  \
# 0           Gratuito  02017-12-20 20 de diciembre de 2017
# 1           Gratuito        02007-05-03 3 de mayo de 2007
# 2           Gratuito              02005-08 agosto de 2005
# 3           Gratuito      02008-01-23 23 de enero de 2008
# 4    Pagar por jugar  02009-11-18 18 de noviembre de 2009
# ..               ...                                  ...
# 90       Suscripción  02011-12-20 20 de diciembre de 2011
# 91          Gratuito      02009-04-28 28 de abril de 2009
# 92          Gratuito    02018-02-28 28 de febrero de 2018
# 93          Gratuito     02017-08-24 24 de agosto de 2017
# 94   Pagar por jugar     02017-08-29 29 de agosto de 2017
#
#              Distribuidor(es)   Ref.
# 0           Krafton / Tencent   [1]​
# 1         Smilegate / Tencent   [2]​
# 2             Nexon / Tencent   [3]​
# 3                     Tencent   [4]​
# 4              Mojang Studios   [5]​
# ..                        ...    ...
# 90            Electronic Arts  [31]​
# 91  Sony Online Entertainment  [31]​
# 92      Daybreak Game Company  [76]​
# 93              Freejam Games  [45]​
# 94            Studio Wildcard  [77]​
#
# [95 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Título                95 non-null     object
#  1   Número                95 non-null     object
#  2   A fecha de            95 non-null     object
#  3   Modelo de negocio     95 non-null     object
#  4   Fecha de lanzamiento  95 non-null     object
#  5   Distribuidor(es)      95 non-null     object
#  6   Ref.                  95 non-null     object
# dtypes: object(7)
# memory usage: 5.3+ KB

# %%
df.tail()
# Out:
#                          Título  \
# 90  Star Wars: The Old Republic
# 91                  Free Realms
# 92                         H1Z1
# 93                    Robocraft
# 94        Ark: Survival Evolved
#
#                                            Número                  A fecha de  \
# 90             10 millones de cuentas registradas      02018-04 abril de 2018
# 91             10 millones de cuentas registradas      02018-04 abril de 2018
# 92                                    10 millones      02018-06 junio de 2018
# 93  10 millones de propietarios en Steam[nota 6]​      02018-07 julio de 2018
# 94                          10  millones[nota 1]​  02017-11 noviembre de 2017
#
#    Modelo de negocio                 Fecha de lanzamiento  \
# 90       Suscripción  02011-12-20 20 de diciembre de 2011
# 91          Gratuito      02009-04-28 28 de abril de 2009
# 92          Gratuito    02018-02-28 28 de febrero de 2018
# 93          Gratuito     02017-08-24 24 de agosto de 2017
# 94   Pagar por jugar     02017-08-29 29 de agosto de 2017
#
#              Distribuidor(es)   Ref.
# 90            Electronic Arts  [31]​
# 91  Sony Online Entertainment  [31]​
# 92      Daybreak Game Company  [76]​
# 93              Freejam Games  [45]​
# 94            Studio Wildcard  [77]​
